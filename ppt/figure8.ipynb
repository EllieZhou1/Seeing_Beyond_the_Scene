# %%
#Baseline Slow-Only on Mini-Kinetics and HAT (full, not mcq)
#Mini-Kinetics: 0.4993963783
# HAT: 0.09617706237 (human), 0.2342052314 (bg)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 1]
labels = ['Slow-Only', ' ']
y = [0.4993963783, 0]

plt.figure(figsize=(4, 5))
plt.xticks(x, labels)
plt.ylim(0.0, 0.55)
plt.bar(x, y, label='Human Accuracy', width=0.4, color='cornflowerblue')
plt.ylabel("Accuracy")
plt.title("Performance on Kinetics")

plt.show()
