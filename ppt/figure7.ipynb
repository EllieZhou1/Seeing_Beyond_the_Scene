# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['Slow-Only', 'CLIP', 'SIGLIP2', 'Intern-VL3', 'GPT 4o-mini']
human = [0.3730715288, 0.4684, 0.4895, 0.612903, 0.582496] #For Intern-VL3, I chose the 8B-8 frame version (bc slow-only and 4o-mini are all w/ 8 frame)

x = np.arange(len(labels))  # the label locations

plt.figure(figsize=(5, 5))
# Plot bars side by side
plt.bar(labels, human, label='Human Accuracy', width=0.6, color='cornflowerblue')

# Labels and legend
plt.xticks(x, labels)
plt.ylabel("Human Accuracy")
plt.title("Performance on Mimetics")
plt.tight_layout()
plt.show()
