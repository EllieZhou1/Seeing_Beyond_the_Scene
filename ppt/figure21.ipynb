# %%
import matplotlib.pyplot as plt

# # Data
gpt_human_accuracy = [
    0.3640256959, 
    0.378947, 
    0.402542, 
    0.384289, 
    0.380042,
    0.400424,
    0.394068,
    0.372881,
    0.368644,
    0.373134,
    0.380042,
    0.368644,
    0.387712, #13
    0.394456, #16 (15 was NAN)
    0.372881, #17
    0.394904, #18
    0.374468, #20
    0.363057, #21
    0.394068, #22,
]
gpt_background_error = [
    0.4668094218, 
    0.509474, 
    0.457627, 
    0.505308,
    0.503185,
    0.45339,
    0.483051,
    0.510593,
    0.519068,
    0.511727,
    0.505308,
    0.521186,
    0.514831, #13
    0.496802, #16
    0.511677, #17
    0.507431, #18
    0.506383, #20
    0.513800, #21
    0.508475, #22
]

internvl3_human_accuracy = [
    0.3150905433,
    0.340443,
    0.371429,
    0.375855,
    0.383903,
    0.338833,
    0.337626,
    0.374648,
    0.380282,
    0.397183,
    0.356137,
    0.374648,
    0.400402,
    0.403622,
    0.416901,
    0.323944,
    0.329175,
    0.364588,
    0.370624,
    0.387123,
    0.331187,
    0.34004,
    0.362575,
    0.383501,
    0.402817,
    0.37666,
    0.404829,
    0.43662,
    0.45996,
    0.472435,
    0.377465,
    0.399598,
    0.435815,
    0.446278,
    0.465996
]

internvl3_background_error = [
    0.4841046278,
    0.494165,
    0.491348,
    0.494165,
    0.488129,
    0.491348,
    0.503018,
    0.484507,
    0.497787,
    0.492555,
    0.496982,
    0.507042,
    0.492555,
    0.504225,
    0.503823,
    0.484105,
    0.494165,
    0.485714,
    0.486519,
    0.476056,
    0.486117,
    0.523541,
    0.516298,
    0.517103,
    0.503823,
    0.505433,
    0.499799,
    0.481288,
    0.475654,
    0.466801,
    0.507847,
    0.5167,
    0.499799,
    0.497787,
    0.477666
]

clip_human_accuracy = 0.3143
clip_background_error = 0.5087

siglip2_human_accuracy = 0.2668
siglip2_background_error = 0.5827

classification_human_accuracy = [
    0.2869215292,
    0.5581488934,
    0.3424547284,
    0.3472837022,
    0.3356136821,
    0.3871227364,
    0.5557344064,
    0.5167002012,
    0.5134808853,
    0.5738430584
]

classification_background_error = [
    0.4736418511,
    0.1171026157,
    0.430583501,
    0.4221327968,
    0.4253521127,
    0.3653923541,
    0.1295774648,
    0.2426559356,
    0.245472837,
    0.1142857143
]


# Create scatter plot
plt.figure(figsize=(7, 7))

plt.scatter(internvl3_human_accuracy, internvl3_background_error, marker='o', s=50, color='lightsalmon', linewidths=4, label='InternVL3')

plt.scatter(gpt_human_accuracy, gpt_background_error, marker='o', s=50, color='lightseagreen', linewidths=4, label='GPT 4o-mini')

plt.scatter(clip_human_accuracy, clip_background_error, marker='o', s=50, color='cornflowerblue', linewidths=4, label='CLIP')


plt.scatter(siglip2_human_accuracy, siglip2_background_error, marker='o', s=50, color='plum', linewidths=4, label='SIGLIP2')

plt.scatter(classification_human_accuracy, classification_background_error, marker='o', s=50, color='gold', linewidths=4, label='Classification')

# Axis labels and title
plt.xlabel("Human Accuracy", fontsize=15)
plt.xticks([0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.yticks([0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.minorticks_on()
plt.grid(which='minor', linestyle=":")
plt.ylabel("Background Error", fontsize=15)
plt.title("GPT 4o-mini Prompt Performance: Background Error vs. Human Accuracy", fontsize=15)
plt.grid(True)
plt.legend(labelspacing=1.2)

plt.xlim(0.20, 0.70)
plt.ylim(0.20, 0.70)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# # Data
# gpt_human_accuracy = [
#     0.3640256959, 
#     0.378947, 
#     0.402542, 
#     0.384289, 
#     0.380042,
#     0.400424,
#     0.394068,
#     0.372881,
#     0.368644,
#     0.373134,
#     0.380042,
#     0.368644,
#     0.387712, #13
#     0.394456, #16 (15 was NAN)
#     0.372881, #17
#     0.394904, #18
#     0.374468, #20
#     0.363057, #21
#     0.394068, #22,
# ]
# gpt_background_error = [
#     0.4668094218, 
#     0.509474, 
#     0.457627, 
#     0.505308,
#     0.503185,
#     0.45339,
#     0.483051,
#     0.510593,
#     0.519068,
#     0.511727,
#     0.505308,
#     0.521186,
#     0.514831, #13
#     0.496802, #16
#     0.511677, #17
#     0.507431, #18
#     0.506383, #20
#     0.513800, #21
#     0.508475, #22
# ]

gpt_full_human_accuracy = [
    0.3905047049,
    0.396323
]

gpt_full_background_error = [
    0.5115483319,
    0.465156
]

internvl3_human_accuracy = [
    0.3150905433,
    0.340443,
    0.371429,
    0.375855,
    0.383903,
    0.338833,
    0.337626,
    0.374648,
    0.380282,
    0.397183,
    0.356137,
    0.374648,
    0.400402,
    0.403622,
    0.416901, 
    0.331187, #14B 1 frame 
    0.34004, #14B 2 frame  
    0.362575, #14B 4 frame  
    0.383501, #14B 8 frame 
    0.402817, #14B 16 frame 
    0.37666, #38B 1 frame  
    0.404829, #38B 2 frame  
    0.43662, #38B 4 frame
    0.45996, #38B 8 frame 
    0.472435, #38B 16 frame 
    0.377465, #78B 1 frame 
    0.399598, #78B 2 frame 
    0.435815, #78B 4 frame 
    0.446278, #78B 8 frame 
    0.465996 #78B 16 frame 
]

internvl3_background_error = [
    0.4841046278, #1B
    0.494165,
    0.491348,
    0.494165,
    0.488129,
    0.491348, #2B
    0.503018,
    0.484507,
    0.497787,
    0.492555, 
    0.496982, #8B
    0.507042,
    0.492555,
    0.504225,
    0.503823, 
    0.486117, #14B
    0.523541,
    0.516298,
    0.517103,
    0.503823, 
    0.505433, #38B
    0.499799,
    0.481288,
    0.475654,
    0.466801, 
    0.507847, #78B
    0.5167,
    0.499799,
    0.497787,
    0.477666
]

clip_human_accuracy = 0.3143
clip_background_error = 0.5087

siglip2_human_accuracy = 0.2668
siglip2_background_error = 0.5827

classification_human_accuracy = [
    0.2869215292,
    0.5581488934,
    0.3424547284,
    0.3472837022,
    0.3356136821,
    0.3871227364,
    0.5557344064,
    0.5167002012,
    0.5134808853,
    0.5738430584
]

classification_background_error = [
    0.4736418511,
    0.1171026157,
    0.430583501,
    0.4221327968,
    0.4253521127,
    0.3653923541,
    0.1295774648,
    0.2426559356,
    0.245472837,
    0.1142857143
]


# Create scatter plot
plt.figure(figsize=(7, 7))

plt.scatter(internvl3_human_accuracy, internvl3_background_error, marker='x', s=100, color='lightsalmon', linewidths=2, label='InternVL3')

plt.scatter(gpt_full_human_accuracy, gpt_full_background_error, marker='x', s=100, color='lightseagreen', linewidths=2, label='GPT 4o-mini')

plt.scatter(clip_human_accuracy, clip_background_error, marker='x', s=100, color='cornflowerblue', linewidths=2, label='CLIP')


plt.scatter(siglip2_human_accuracy, siglip2_background_error, marker='x', s=100, color='plum', linewidths=2, label='SIGLIP2')

plt.scatter(classification_human_accuracy, classification_background_error, marker='x', s=100, color='gold', linewidths=2, label='Classification')

# Axis labels and title
plt.xlabel("Swap Human Accuracy", fontsize=15)
plt.xticks([0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.yticks([0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70])
plt.minorticks_on()
plt.grid(which='minor', linestyle=":")
plt.ylabel("Swap Background Error", fontsize=15)
plt.title("Comparison of all Models on HAT Action-Swap MCQ", fontsize=15)
plt.grid(True)
plt.legend(labelspacing=1.2)

plt.xlim(0.10, 0.70)
plt.ylim(0.10, 0.70)

plt.tight_layout()
plt.show()
