# %%
from openai import OpenAI
import openai
import os
import base64

# %%
# Initialize Azure OpenAI client
client = OpenAI(
    api_key="",
    # api_version="2024-02-01",
    # azure_endpoint="https://api-ai-sandbox.princeton.edu/",
)

def encode_image_to_base64(image_path):
    with open(image_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")
        
image_path = "/n/fs/visualai-scr/temp_LLP/ellie/slowfast_kinetics/dataset/action_swap/original_action_swap/sample_000000_deadlifting_to_juggling soccer ball_f8dp7wR4GWg_000003_000013_bg_MCV13GHst20_000002_000012/000020.jpg"
# Encode all images to base64
encoded_images = []
for image_pathe in [image_path, image_path, image_path, image_path]:
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"Image file not found: {image_pathe}")
    encoded_images.append(encode_image_to_base64(image_pathe))

# Prepare the content for the API call
content = [
        {
            "type": "text",
            "text": """Describe the given video."""
        },
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{encode_image_to_base64(image_path)}",
                "detail": "low"
            }
        },
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{encode_image_to_base64(image_path)}",
                "detail": "low"
            }
        },
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{encode_image_to_base64(image_path)}",
                "detail": "low"
            }
        },
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{encode_image_to_base64(image_path)}",
                "detail": "low"
            }
        },
    ]

response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {
            "role": "user",
            "content": content
        }
    ],
    max_tokens=1000,
    temperature=0.7
)
print("\n"+response.choices[0].message.content)
print(response.usage.prompt_tokens, response.usage.completion_tokens)
# Out:
# The video features a person performing a deadlift exercise on a rooftop setting. The individual is dressed in a teal shirt and black pants, with visible socks and shoes. The background includes a cityscape, with buildings and a clear sky. The person appears to be focused on maintaining proper form while lifting, showcasing a blend of fitness activity and an urban environment.
# 11344 71
