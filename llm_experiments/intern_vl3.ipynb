# %%
import numpy as np
import torch
import torchvision.transforms as T
from decord import VideoReader, cpu
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
import os
import pandas as pd

# %%
# def load_video(video_path, bound=None, input_size=448, max_num=1, num_segments=32):
#     vr = VideoReader(video_path, ctx=cpu(0), num_threads=1)
#     max_frame = len(vr) - 1
#     fps = float(vr.get_avg_fps())

#     pixel_values_list, num_patches_list = [], []
#     transform = build_transform(input_size=input_size)
#     frame_indices = get_index(bound, fps, max_frame, first_idx=0, num_segments=num_segments)
#     for frame_index in frame_indices:
#         img = Image.fromarray(vr[frame_index].asnumpy()).convert('RGB')
#         img = dynamic_preprocess(img, image_size=input_size, use_thumbnail=True, max_num=max_num)
#         pixel_values = [transform(tile) for tile in img]
#         pixel_values = torch.stack(pixel_values)
#         num_patches_list.append(pixel_values.shape[0])
#         pixel_values_list.append(pixel_values)
#     pixel_values = torch.cat(pixel_values_list)
#     return pixel_values, num_patches_list

# %%
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)

def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([
        T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
        T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
        T.ToTensor(),
        T.Normalize(mean=MEAN, std=STD)
    ])
    return transform

def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float('inf')
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio

def dynamic_preprocess(image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set(
        (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
        i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(
        aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = (
            (i % (target_width // image_size)) * image_size,
            (i // (target_width // image_size)) * image_size,
            ((i % (target_width // image_size)) + 1) * image_size,
            ((i // (target_width // image_size)) + 1) * image_size
        )
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images

# %%
# !pip install -U huggingface_hub
# !huggingface-cli download --resume-download --local-dir-use-symlinks False OpenGVLab/InternVL2_5-8B --local-dir InternVL2_5-8B
# Out:
# Requirement already satisfied: huggingface_hub in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (0.33.4)
# Requirement already satisfied: filelock in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages (from requests->huggingface_hub) (2025.6.15)
# /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Fetching 28 files:   0%|                                 | 0/28 [00:00<?, ?it/s]/n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Downloading 'config.json' to 'InternVL2_5-8B/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.90be7fce58a2f69f59fb06159c8de0cfa5507888.incomplete'
# Downloading 'added_tokens.json' to 'InternVL2_5-8B/.cache/huggingface/download/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.35f5893c8e29d6102945a953529819a2d56c62a9.incomplete'
#
# config.json: 4.05kB [00:00, 22.4MB/s]
# Download complete. Moving file to InternVL2_5-8B/config.json
#
# added_tokens.json: 100%|███████████████████████| 179/179 [00:00<00:00, 2.07MB/s]Downloading '.gitattributes' to 'InternVL2_5-8B/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.8146268512808cfd9623536c65bf0d0ef7efdc45.incomplete'
#
# Download complete. Moving file to InternVL2_5-8B/added_tokens.json
#
# .gitattributes: 1.63kB [00:00, 11.7MB/s]
# Download complete. Moving file to InternVL2_5-8B/.gitattributes
# Downloading 'configuration_internlm2.py' to 'InternVL2_5-8B/.cache/huggingface/download/pCb1JrLKfwPgD6-09aFLDP6Cnv0=.282b13b1e2066ecc074ecae87b35a19d251f0ed7.incomplete'
# Downloading 'conversation.py' to 'InternVL2_5-8B/.cache/huggingface/download/DEizyvx9GSqAZTOB7ZJABNlK3H0=.5a771766f21ce3aeeb99b286fb8d188b0038a547.incomplete'
# Still waiting to acquire lock on InternVL2_5-8B/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Downloading 'examples/image2.jpg' to 'InternVL2_5-8B/.cache/huggingface/download/examples/3C9-6_0ixe-0KhycCBHC5dl9M-w=.08487494b8dc08d44bc36491adf3ab89ff30d13a3122da86f3cd67cad89eeee8.incomplete'
#
# configuration_internlm2.py: 0.00B [00:00, ?B/s]
#
# configuration_internlm2.py: 7.00kB [00:00, 2.71MB/s]
# conversation.py: 15.3kB [00:00, 51.7MB/s]
# Download complete. Moving file to InternVL2_5-8B/configuration_internlm2.py
# Download complete. Moving file to InternVL2_5-8B/conversation.py
# Downloading 'eval_llm_benchmark.log' to 'InternVL2_5-8B/.cache/huggingface/download/4TnQeylNv-9uJQo4xrvcrnVW30I=.bd17c0d6917dc4080f27765d7084da9e9f6857ec.incomplete'
#
# eval_llm_benchmark.log: 49.3kB [00:00, 159MB/s]
# Download complete. Moving file to InternVL2_5-8B/eval_llm_benchmark.log
# Downloading 'examples/image1.jpg' to 'InternVL2_5-8B/.cache/huggingface/download/examples/DHLHdPXckD7SCnfl3p4-2q-6a4Q=.fd9891ef7e00774157a9dcd726b2ea9fa0c5ecff.incomplete'
#
# image1.jpg:   0%|                                   | 0.00/78.1k [00:00<?, ?B/s]
#
# image2.jpg:   0%|                                    | 0.00/126k [00:00<?, ?B/s]Downloading 'examples/red-panda.mp4' to 'InternVL2_5-8B/.cache/huggingface/download/examples/b499fO5pocl6nV8kye2RCPcqkBk=.d921c07bb97224d65a37801541d246067f0d506f08723ffa1ad85c217907ccb8.incomplete'
# image1.jpg: 100%|██████████████████████████| 78.1k/78.1k [00:00<00:00, 33.8MB/s]
# Download complete. Moving file to InternVL2_5-8B/examples/image1.jpg
# image2.jpg: 100%|████████████████████████████| 126k/126k [00:00<00:00, 32.4MB/s]
# Downloading 'README.md' to 'InternVL2_5-8B/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.0169bf3a24d2b0d796174f9d2b3d9072a70b2f44.incomplete'
# Downloading 'configuration_intern_vit.py' to 'InternVL2_5-8B/.cache/huggingface/download/_MrF22XZuffGbJP8rB83lHzm0u4=.7e630c456eb9cf350e55bf850c3ff72f445a7e17.incomplete'
# Download complete. Moving file to InternVL2_5-8B/examples/image2.jpg
# Downloading 'generation_config.json' to 'InternVL2_5-8B/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.d45dc4fdf649b1096e6d30f54fa59c1366ddecfb.incomplete'
#
# configuration_intern_vit.py: 0.00B [00:00, ?B/s]
#
# README.md: 0.00B [00:00, ?B/s]
#
#
# generation_config.json: 100%|██████████████████| 115/115 [00:00<00:00, 1.33MB/s]
# configuration_intern_vit.py: 5.55kB [00:00, 3.16MB/s]
# README.md: 34.0kB [00:00, 24.9MB/s]
# Download complete. Moving file to InternVL2_5-8B/generation_config.json
# Download complete. Moving file to InternVL2_5-8B/configuration_intern_vit.py
# Download complete. Moving file to InternVL2_5-8B/README.md
# Downloading 'model-00001-of-00004.safetensors' to 'InternVL2_5-8B/.cache/huggingface/download/IO4xwqmZYzFmxznkwkiNSBwO1H0=.c9815f2a1c042cb4b6db939063a7b3ea6533c2ed0ffa3b4d79ac3c7d5cb5be9c.incomplete'
# Fetching 28 files:   7%|█▊                       | 2/28 [00:00<00:02, 10.33it/s]
# red-panda.mp4:   0%|                                | 0.00/1.87M [00:00<?, ?B/s]Downloading 'configuration_internvl_chat.py' to 'InternVL2_5-8B/.cache/huggingface/download/DsLREbI1OaCt0aQRMkT6-8j8O0Q=.50d3ee82772f8abb4fa1ae6a7c80899df7ddd941.incomplete'
#
#
# configuration_internvl_chat.py: 4.09kB [00:00, 29.1MB/s]A
# Downloading 'model-00002-of-00004.safetensors' to 'InternVL2_5-8B/.cache/huggingface/download/t9msAuTjAZjuQnmzGOwTjiptvIU=.fbc4b8d534056f7b700276ddc2e52a407767a7803d788144c620a357df799d6f.incomplete'
# Download complete. Moving file to InternVL2_5-8B/configuration_internvl_chat.py
# Downloading 'model-00003-of-00004.safetensors' to 'InternVL2_5-8B/.cache/huggingface/download/DaGOU-KRMVrY0aYktrsE34tL0Bs=.0b5544a5021413d7b7e16f3a53800806474293df5c705101926634122c6c4103.incomplete'
# red-panda.mp4: 100%|███████████████████████| 1.87M/1.87M [00:00<00:00, 74.8MB/s]
# Downloading 'modeling_intern_vit.py' to 'InternVL2_5-8B/.cache/huggingface/download/RTKxUQNMcYzd9NdDH76_hzPG1AI=.233b0293451a13c7b5211d65633deb73a13b240c.incomplete'
#
# model-00003-of-00004.safetensors:   0%|             | 0.00/4.92G [00:00<?, ?B/s]Download complete. Moving file to InternVL2_5-8B/examples/red-panda.mp4
#
#
# modeling_intern_vit.py: 18.1kB [00:00, 86.1MB/s]A
# Download complete. Moving file to InternVL2_5-8B/modeling_intern_vit.py
#
#
# model-00002-of-00004.safetensors:   0%|             | 0.00/4.92G [00:00<?, ?B/s]Downloading 'model.safetensors.index.json' to 'InternVL2_5-8B/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.8b024ee06fb58c2607a1c54a04b8ee0749d14f2c.incomplete'
#
#
#
# model.safetensors.index.json: 51.2kB [00:00, 199MB/s][A
# Download complete. Moving file to InternVL2_5-8B/model.safetensors.index.json
# Downloading 'modeling_internlm2.py' to 'InternVL2_5-8B/.cache/huggingface/download/E2QF5AdXAeP81l7egx6W50eOQ50=.7c8c24d873f6ecd152d00fd65371e23ead981e1d.incomplete'
#
#
#
# modeling_internlm2.py: 61.2kB [00:00, 134MB/s][A
# Download complete. Moving file to InternVL2_5-8B/modeling_internlm2.py
# Downloading 'preprocessor_config.json' to 'InternVL2_5-8B/.cache/huggingface/download/PYH5dHjks7Ei0Yd3X0Z8xIwsCNQ=.dfd7e50d9d4e67cd679b16b337b419a0c6cfa849.incomplete'
# Downloading 'modeling_internvl_chat.py' to 'InternVL2_5-8B/.cache/huggingface/download/0iPZ4DgR3ByT0g6iDwA8qs1ngbc=.6dd05026716317d3483b2abd4a573e61cf1048c7.incomplete'
#
#
#
# preprocessor_config.json: 100%|████████████████| 287/287 [00:00<00:00, 3.36MB/s]
#
#
#
# modeling_internvl_chat.py: 16.0kB [00:00, 77.3MB/s]A
# Download complete. Moving file to InternVL2_5-8B/preprocessor_config.json
# Download complete. Moving file to InternVL2_5-8B/modeling_internvl_chat.py
# Downloading 'runs/Nov18_19-03-50_HOST-10-140-60-23/events.out.tfevents.1731928182.HOST-10-140-60-23.129254.0' to 'InternVL2_5-8B/.cache/huggingface/download/runs/Nov18_19-03-50_HOST-10-140-60-23/L-HunRfm0rA17FYIPT-UWF7-BkM=.e3dd92f5f96eb3e07774dc14ca9cbeedc6470c897e61c303ad5a48059f90a650.incomplete'
#
# model-00003-of-00004.safetensors:   0%|     | 21.0M/4.92G [00:00<00:24, 201MB/s]
#
# model-00002-of-00004.safetensors:   0%|     | 21.0M/4.92G [00:00<00:24, 196MB/s]
#
#
# (…)ts.1731928182.HOST-10-140-60-23.129254.0:   0%|   | 0.00/854k [00:00<?, ?B/s]
#
#
#
# (…)ts.1731928182.HOST-10-140-60-23.129254.0: 100%|█| 854k/854k [00:00<00:00, 77.
# Downloading 'tokenization_internlm2_fast.py' to 'InternVL2_5-8B/.cache/huggingface/download/IslcfO3AXhtL5J4F7mnyuhOsLsE=.aa0fccbd0f1d029d79e19821f2edcb01b594537c.incomplete'
# Downloading 'tokenization_internlm2.py' to 'InternVL2_5-8B/.cache/huggingface/download/OUyF0rYwwzC5PYa5zbYM_tLNMcY=.1be581da37ef678de65f2737493fc0ed7160446e.incomplete'
# Download complete. Moving file to InternVL2_5-8B/runs/Nov18_19-03-50_HOST-10-140-60-23/events.out.tfevents.1731928182.HOST-10-140-60-23.129254.0
#
#
#
# tokenization_internlm2_fast.py: 7.79kB [00:00, 38.5MB/s]A
#
#
#
# tokenization_internlm2.py: 0.00B [00:00, ?B/s]Download complete. Moving file to InternVL2_5-8B/tokenization_internlm2_fast.py
# tokenization_internlm2.py: 8.79kB [00:00, 1.54MB/s]
# Download complete. Moving file to InternVL2_5-8B/tokenization_internlm2.py
# Downloading 'tokenizer.model' to 'InternVL2_5-8B/.cache/huggingface/download/7iVfz3cUOMr-hyjiqqRDHEwVBAM=.f868398fc4e05ee1e8aeba95ddf18ddcc45b8bce55d5093bead5bbf80429b48b.incomplete'
# Downloading 'tokenizer_config.json' to 'InternVL2_5-8B/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.c8e0cbeffaa659a63b960b3649d6a3360239b697.incomplete'
#
# model-00003-of-00004.safetensors:   1%|     | 52.4M/4.92G [00:00<00:21, 226MB/s]
#
# model-00002-of-00004.safetensors:   1%|     | 52.4M/4.92G [00:00<00:21, 231MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0%|     | 21.0M/4.94G [00:00<00:27, 180MB/s]
#
#
# tokenizer_config.json: 0.00B [00:00, ?B/s]
#
#
#
#
# tokenizer_config.json: 4.01kB [00:00, 11.3MB/s]     | 0.00/1.48M [00:00<?, ?B/s]
# Download complete. Moving file to InternVL2_5-8B/tokenizer_config.json
# Downloading 'special_tokens_map.json' to 'InternVL2_5-8B/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.cbf34a50d27c43ed8d1e2823b800b4e6f66e637a.incomplete'
# tokenizer.model: 100%|█████████████████████| 1.48M/1.48M [00:00<00:00, 75.5MB/s]
# Download complete. Moving file to InternVL2_5-8B/tokenizer.model
#
#
#
# special_tokens_map.json: 100%|█████████████████| 844/844 [00:00<00:00, 9.10MB/s]
# Download complete. Moving file to InternVL2_5-8B/special_tokens_map.json
# Downloading 'model-00004-of-00004.safetensors' to 'InternVL2_5-8B/.cache/huggingface/download/-dFtyT7kcgbTHt1cy9JKqruJCR4=.304352082d3656f355ccac2833ab1faef475788e1d14973c5629d5721bd09b72.incomplete'
#
# model-00003-of-00004.safetensors:   2%|     | 83.9M/4.92G [00:00<00:20, 234MB/s]
#
# model-00002-of-00004.safetensors:   2%|     | 83.9M/4.92G [00:00<00:20, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:   1%|     | 52.4M/4.94G [00:00<00:22, 218MB/s]
#
#
# model-00004-of-00004.safetensors:   0%|             | 0.00/1.38G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   2%|▏     | 115M/4.92G [00:00<00:20, 235MB/s]
#
# model-00002-of-00004.safetensors:   2%|▏     | 115M/4.92G [00:00<00:20, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:   2%|     | 83.9M/4.94G [00:00<00:21, 230MB/s]
#
#
# model-00004-of-00004.safetensors:   2%|     | 21.0M/1.38G [00:00<00:07, 176MB/s]
# model-00003-of-00004.safetensors:   3%|▏     | 147M/4.92G [00:00<00:19, 239MB/s]
#
# model-00002-of-00004.safetensors:   3%|▏     | 147M/4.92G [00:00<00:20, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:   2%|▏     | 115M/4.94G [00:00<00:20, 233MB/s]
#
#
# model-00004-of-00004.safetensors:   4%|▏    | 52.4M/1.38G [00:00<00:06, 217MB/s]
# model-00003-of-00004.safetensors:   4%|▏     | 178M/4.92G [00:00<00:19, 240MB/s]
#
# model-00002-of-00004.safetensors:   4%|▏     | 178M/4.92G [00:00<00:19, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:   3%|▏     | 147M/4.94G [00:00<00:20, 239MB/s]
#
#
# model-00004-of-00004.safetensors:   6%|▎    | 83.9M/1.38G [00:00<00:05, 223MB/s]
# model-00003-of-00004.safetensors:   4%|▎     | 210M/4.92G [00:00<00:19, 240MB/s]
#
# model-00002-of-00004.safetensors:   4%|▎     | 210M/4.92G [00:00<00:19, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:   4%|▏     | 178M/4.94G [00:00<00:19, 240MB/s]
#
#
# model-00004-of-00004.safetensors:   8%|▌     | 115M/1.38G [00:00<00:05, 230MB/s]
#
#
#
# model-00001-of-00004.safetensors:   4%|▎     | 210M/4.94G [00:00<00:19, 243MB/s]
# model-00003-of-00004.safetensors:   5%|▎     | 241M/4.92G [00:01<00:19, 239MB/s]
#
# model-00002-of-00004.safetensors:   5%|▎     | 241M/4.92G [00:01<00:19, 236MB/s]
#
#
# model-00004-of-00004.safetensors:  11%|▋     | 147M/1.38G [00:00<00:05, 232MB/s]
#
#
#
# model-00001-of-00004.safetensors:   5%|▎     | 241M/4.94G [00:01<00:19, 243MB/s]
# model-00003-of-00004.safetensors:   6%|▎     | 273M/4.92G [00:01<00:19, 240MB/s]
#
# model-00002-of-00004.safetensors:   6%|▎     | 273M/4.92G [00:01<00:19, 242MB/s]
#
#
# model-00004-of-00004.safetensors:  13%|▊     | 178M/1.38G [00:00<00:05, 231MB/s]
#
#
#
# model-00001-of-00004.safetensors:   6%|▎     | 273M/4.94G [00:01<00:20, 226MB/s]
# model-00003-of-00004.safetensors:   6%|▎     | 304M/4.92G [00:01<00:20, 224MB/s]
#
# model-00002-of-00004.safetensors:   6%|▎     | 304M/4.92G [00:01<00:20, 222MB/s]
#
#
# model-00004-of-00004.safetensors:  15%|▉     | 210M/1.38G [00:00<00:05, 209MB/s]
#
#
#
# model-00001-of-00004.safetensors:   6%|▎     | 304M/4.94G [00:01<00:20, 232MB/s]
# model-00003-of-00004.safetensors:   7%|▍     | 336M/4.92G [00:01<00:20, 228MB/s]
#
# model-00002-of-00004.safetensors:   7%|▍     | 336M/4.92G [00:01<00:20, 227MB/s]
#
#
# model-00004-of-00004.safetensors:  17%|█     | 241M/1.38G [00:01<00:05, 220MB/s]
#
#
#
# model-00001-of-00004.safetensors:   7%|▍     | 336M/4.94G [00:01<00:19, 235MB/s]
# model-00003-of-00004.safetensors:   7%|▍     | 367M/4.92G [00:01<00:19, 232MB/s]
#
# model-00002-of-00004.safetensors:   7%|▍     | 367M/4.92G [00:01<00:19, 232MB/s]
#
#
# model-00004-of-00004.safetensors:  20%|█▏    | 273M/1.38G [00:01<00:04, 225MB/s]
#
#
#
# model-00001-of-00004.safetensors:   7%|▍     | 367M/4.94G [00:01<00:19, 239MB/s]
#
# model-00002-of-00004.safetensors:   8%|▍     | 398M/4.92G [00:01<00:19, 238MB/s]
# model-00003-of-00004.safetensors:   8%|▍     | 398M/4.92G [00:01<00:19, 233MB/s]
#
#
# model-00004-of-00004.safetensors:  22%|█▎    | 304M/1.38G [00:01<00:04, 231MB/s]
#
#
#
# model-00001-of-00004.safetensors:   8%|▍     | 398M/4.94G [00:01<00:18, 241MB/s]
#
# model-00002-of-00004.safetensors:   9%|▌     | 430M/4.92G [00:01<00:18, 241MB/s]
# model-00003-of-00004.safetensors:   9%|▌     | 430M/4.92G [00:01<00:18, 236MB/s]
#
#
# model-00004-of-00004.safetensors:  24%|█▍    | 336M/1.38G [00:01<00:04, 233MB/s]
#
#
#
# model-00001-of-00004.safetensors:   9%|▌     | 430M/4.94G [00:01<00:18, 241MB/s]
#
# model-00002-of-00004.safetensors:   9%|▌     | 461M/4.92G [00:01<00:18, 240MB/s]
# model-00003-of-00004.safetensors:   9%|▌     | 461M/4.92G [00:01<00:18, 238MB/s]
#
#
# model-00004-of-00004.safetensors:  27%|█▌    | 367M/1.38G [00:01<00:04, 233MB/s]
#
#
#
# model-00001-of-00004.safetensors:   9%|▌     | 461M/4.94G [00:01<00:18, 242MB/s]
#
# model-00002-of-00004.safetensors:  10%|▌     | 493M/4.92G [00:02<00:18, 240MB/s]
# model-00003-of-00004.safetensors:  10%|▌     | 493M/4.92G [00:02<00:18, 238MB/s]
#
#
# model-00004-of-00004.safetensors:  29%|█▋    | 398M/1.38G [00:01<00:04, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  10%|▌     | 493M/4.94G [00:02<00:18, 242MB/s]
#
# model-00002-of-00004.safetensors:  11%|▋     | 524M/4.92G [00:02<00:18, 243MB/s]
# model-00003-of-00004.safetensors:  11%|▋     | 524M/4.92G [00:02<00:18, 240MB/s]
#
#
# model-00004-of-00004.safetensors:  31%|█▊    | 430M/1.38G [00:01<00:04, 234MB/s]
#
#
#
# model-00001-of-00004.safetensors:  11%|▋     | 524M/4.94G [00:02<00:18, 244MB/s]
#
# model-00002-of-00004.safetensors:  11%|▋     | 556M/4.92G [00:02<00:17, 244MB/s]
# model-00003-of-00004.safetensors:  11%|▋     | 556M/4.92G [00:02<00:18, 241MB/s]
#
#
# model-00004-of-00004.safetensors:  33%|██    | 461M/1.38G [00:02<00:03, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  11%|▋     | 556M/4.94G [00:02<00:18, 241MB/s]
#
# model-00002-of-00004.safetensors:  12%|▋     | 587M/4.92G [00:02<00:17, 242MB/s]
# model-00003-of-00004.safetensors:  12%|▋     | 587M/4.92G [00:02<00:18, 233MB/s]
#
#
# model-00004-of-00004.safetensors:  36%|██▏   | 493M/1.38G [00:02<00:03, 233MB/s]
#
#
#
# model-00001-of-00004.safetensors:  12%|▋     | 587M/4.94G [00:02<00:17, 244MB/s]
#
# model-00002-of-00004.safetensors:  13%|▊     | 619M/4.92G [00:02<00:17, 245MB/s]
# model-00003-of-00004.safetensors:  13%|▊     | 619M/4.92G [00:02<00:18, 235MB/s]
#
#
# model-00004-of-00004.safetensors:  38%|██▎   | 524M/1.38G [00:02<00:03, 230MB/s]
#
#
#
# model-00001-of-00004.safetensors:  13%|▊     | 619M/4.94G [00:02<00:17, 244MB/s]
#
# model-00002-of-00004.safetensors:  13%|▊     | 650M/4.92G [00:02<00:17, 246MB/s]
# model-00003-of-00004.safetensors:  13%|▊     | 650M/4.92G [00:02<00:18, 235MB/s]
#
#
# model-00004-of-00004.safetensors:  40%|██▍   | 556M/1.38G [00:02<00:03, 221MB/s]
#
#
#
# model-00001-of-00004.safetensors:  13%|▊     | 650M/4.94G [00:02<00:17, 245MB/s]
# model-00003-of-00004.safetensors:  14%|▊     | 682M/4.92G [00:02<00:17, 237MB/s]
#
# model-00002-of-00004.safetensors:  14%|▊     | 682M/4.92G [00:02<00:19, 222MB/s]
#
#
#
# model-00001-of-00004.safetensors:  14%|▊     | 682M/4.94G [00:02<00:17, 243MB/s]
#
#
# model-00004-of-00004.safetensors:  43%|██▌   | 587M/1.38G [00:02<00:03, 217MB/s]
# model-00003-of-00004.safetensors:  15%|▊     | 713M/4.92G [00:03<00:17, 238MB/s]
#
# model-00002-of-00004.safetensors:  15%|▊     | 713M/4.92G [00:03<00:18, 230MB/s]
#
#
#
# model-00001-of-00004.safetensors:  14%|▊     | 713M/4.94G [00:02<00:17, 244MB/s]
#
#
# model-00004-of-00004.safetensors:  45%|██▋   | 619M/1.38G [00:02<00:03, 213MB/s]
# model-00003-of-00004.safetensors:  15%|▉     | 744M/4.92G [00:03<00:17, 239MB/s]
#
# model-00002-of-00004.safetensors:  15%|▉     | 744M/4.92G [00:03<00:17, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  15%|▉     | 744M/4.94G [00:03<00:17, 244MB/s]
#
# model-00002-of-00004.safetensors:  16%|▉     | 776M/4.92G [00:03<00:17, 239MB/s]
# model-00003-of-00004.safetensors:  16%|▉     | 776M/4.92G [00:03<00:17, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  47%|██▊   | 650M/1.38G [00:02<00:03, 213MB/s]
#
#
#
# model-00001-of-00004.safetensors:  16%|▉     | 776M/4.94G [00:03<00:17, 243MB/s]
#
# model-00002-of-00004.safetensors:  16%|▉     | 807M/4.92G [00:03<00:17, 239MB/s]
# model-00003-of-00004.safetensors:  16%|▉     | 807M/4.92G [00:03<00:17, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  49%|██▉   | 682M/1.38G [00:03<00:03, 214MB/s]
#
#
#
# model-00001-of-00004.safetensors:  16%|▉     | 807M/4.94G [00:03<00:17, 236MB/s]
# model-00003-of-00004.safetensors:  17%|█     | 839M/4.92G [00:03<00:16, 241MB/s]
#
# model-00002-of-00004.safetensors:  17%|█     | 839M/4.92G [00:03<00:17, 238MB/s]
#
#
# model-00004-of-00004.safetensors:  52%|███   | 713M/1.38G [00:03<00:03, 214MB/s]
#
#
#
# model-00001-of-00004.safetensors:  17%|█     | 839M/4.94G [00:03<00:17, 241MB/s]
# model-00003-of-00004.safetensors:  18%|█     | 870M/4.92G [00:03<00:16, 243MB/s]
#
# model-00002-of-00004.safetensors:  18%|█     | 870M/4.92G [00:03<00:16, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  54%|███▏  | 744M/1.38G [00:03<00:02, 216MB/s]
#
#
#
# model-00001-of-00004.safetensors:  18%|█     | 870M/4.94G [00:03<00:17, 236MB/s]
# model-00003-of-00004.safetensors:  18%|█     | 902M/4.92G [00:03<00:16, 243MB/s]
#
# model-00002-of-00004.safetensors:  18%|█     | 902M/4.92G [00:03<00:16, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  56%|███▍  | 776M/1.38G [00:03<00:02, 218MB/s]
#
#
#
# model-00001-of-00004.safetensors:  18%|█     | 902M/4.94G [00:03<00:16, 243MB/s]
# model-00003-of-00004.safetensors:  19%|█▏    | 933M/4.92G [00:03<00:16, 244MB/s]
#
# model-00002-of-00004.safetensors:  19%|█▏    | 933M/4.92G [00:03<00:16, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  59%|███▌  | 807M/1.38G [00:03<00:02, 221MB/s]
#
#
#
# model-00001-of-00004.safetensors:  19%|█▏    | 933M/4.94G [00:03<00:16, 241MB/s]
# model-00003-of-00004.safetensors:  20%|█▏    | 965M/4.92G [00:04<00:16, 243MB/s]
#
# model-00002-of-00004.safetensors:  20%|█▏    | 965M/4.92G [00:04<00:16, 234MB/s]
#
#
# model-00004-of-00004.safetensors:  61%|███▋  | 839M/1.38G [00:03<00:02, 223MB/s]
#
#
#
# model-00001-of-00004.safetensors:  20%|█▏    | 965M/4.94G [00:04<00:16, 243MB/s]
# model-00003-of-00004.safetensors:  20%|█▏    | 996M/4.92G [00:04<00:16, 241MB/s]
#
# model-00002-of-00004.safetensors:  20%|█▏    | 996M/4.92G [00:04<00:16, 241MB/s]
#
#
# model-00004-of-00004.safetensors:  63%|███▊  | 870M/1.38G [00:03<00:02, 224MB/s]
#
#
#
# model-00001-of-00004.safetensors:  20%|█▏    | 996M/4.94G [00:04<00:16, 240MB/s]
# model-00003-of-00004.safetensors:  21%|█    | 1.03G/4.92G [00:04<00:16, 239MB/s]
#
# model-00002-of-00004.safetensors:  21%|█    | 1.03G/4.92G [00:04<00:16, 242MB/s]
#
#
# model-00004-of-00004.safetensors:  65%|███▉  | 902M/1.38G [00:04<00:02, 229MB/s]
#
#
#
# model-00001-of-00004.safetensors:  21%|█    | 1.03G/4.94G [00:04<00:16, 241MB/s]
# model-00003-of-00004.safetensors:  22%|█    | 1.06G/4.92G [00:04<00:15, 241MB/s]
#
# model-00002-of-00004.safetensors:  22%|█    | 1.06G/4.92G [00:04<00:15, 242MB/s]
#
#
#
# model-00001-of-00004.safetensors:  21%|█    | 1.06G/4.94G [00:04<00:15, 243MB/s]
#
#
# model-00004-of-00004.safetensors:  68%|████  | 933M/1.38G [00:04<00:01, 232MB/s]
# model-00003-of-00004.safetensors:  22%|█    | 1.09G/4.92G [00:04<00:15, 242MB/s]
#
# model-00002-of-00004.safetensors:  22%|█    | 1.09G/4.92G [00:04<00:15, 244MB/s]
#
#
#
# model-00001-of-00004.safetensors:  22%|█    | 1.09G/4.94G [00:04<00:15, 243MB/s]
#
#
# model-00004-of-00004.safetensors:  70%|████▏ | 965M/1.38G [00:04<00:01, 234MB/s]
#
# model-00002-of-00004.safetensors:  23%|█▏   | 1.12G/4.92G [00:04<00:15, 244MB/s]
# model-00003-of-00004.safetensors:  23%|█▏   | 1.12G/4.92G [00:04<00:16, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  23%|█▏   | 1.12G/4.94G [00:04<00:15, 241MB/s]
#
#
# model-00004-of-00004.safetensors:  72%|████▎ | 996M/1.38G [00:04<00:01, 225MB/s]
#
# model-00002-of-00004.safetensors:  23%|█▏   | 1.15G/4.92G [00:04<00:16, 234MB/s]
# model-00003-of-00004.safetensors:  23%|█▏   | 1.15G/4.92G [00:04<00:16, 228MB/s]
#
#
#
# model-00001-of-00004.safetensors:  23%|█▏   | 1.15G/4.94G [00:04<00:16, 236MB/s]
#
#
# model-00004-of-00004.safetensors:  75%|███▋ | 1.03G/1.38G [00:04<00:01, 229MB/s]
#
# model-00002-of-00004.safetensors:  24%|█▏   | 1.18G/4.92G [00:04<00:15, 235MB/s]
# model-00003-of-00004.safetensors:  24%|█▏   | 1.18G/4.92G [00:05<00:15, 234MB/s]
#
#
#
# model-00001-of-00004.safetensors:  24%|█▏   | 1.18G/4.94G [00:04<00:15, 239MB/s]
#
#
# model-00004-of-00004.safetensors:  77%|███▊ | 1.06G/1.38G [00:04<00:01, 232MB/s]
#
# model-00002-of-00004.safetensors:  25%|█▏   | 1.22G/4.92G [00:05<00:15, 237MB/s]
# model-00003-of-00004.safetensors:  25%|█▏   | 1.22G/4.92G [00:05<00:15, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  25%|█▏   | 1.22G/4.94G [00:05<00:15, 237MB/s]
#
#
# model-00004-of-00004.safetensors:  79%|███▉ | 1.09G/1.38G [00:04<00:01, 233MB/s]
#
# model-00002-of-00004.safetensors:  25%|█▎   | 1.25G/4.92G [00:05<00:15, 240MB/s]
# model-00003-of-00004.safetensors:  25%|█▎   | 1.25G/4.92G [00:05<00:15, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  25%|█▎   | 1.25G/4.94G [00:05<00:15, 238MB/s]
#
#
# model-00004-of-00004.safetensors:  81%|████ | 1.12G/1.38G [00:04<00:01, 232MB/s]
#
# model-00002-of-00004.safetensors:  26%|█▎   | 1.28G/4.92G [00:05<00:15, 239MB/s]
# model-00003-of-00004.safetensors:  26%|█▎   | 1.28G/4.92G [00:05<00:15, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  26%|█▎   | 1.28G/4.94G [00:05<00:15, 240MB/s]
#
#
# model-00004-of-00004.safetensors:  84%|████▏| 1.15G/1.38G [00:05<00:00, 233MB/s]
#
# model-00002-of-00004.safetensors:  27%|█▎   | 1.31G/4.92G [00:05<00:15, 239MB/s]
# model-00003-of-00004.safetensors:  27%|█▎   | 1.31G/4.92G [00:05<00:15, 240MB/s]
#
#
#
# model-00001-of-00004.safetensors:  27%|█▎   | 1.31G/4.94G [00:05<00:15, 238MB/s]
#
#
# model-00004-of-00004.safetensors:  86%|████▎| 1.18G/1.38G [00:05<00:00, 236MB/s]
# model-00003-of-00004.safetensors:  27%|█▎   | 1.34G/4.92G [00:05<00:14, 240MB/s]
#
# model-00002-of-00004.safetensors:  27%|█▎   | 1.34G/4.92G [00:05<00:17, 209MB/s]
#
#
#
# model-00001-of-00004.safetensors:  27%|█▎   | 1.34G/4.94G [00:05<00:14, 244MB/s]
#
#
# model-00004-of-00004.safetensors:  88%|████▍| 1.22G/1.38G [00:05<00:00, 238MB/s]
# model-00003-of-00004.safetensors:  28%|█▍   | 1.37G/4.92G [00:05<00:14, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  28%|█▍   | 1.37G/4.94G [00:05<00:14, 244MB/s]
#
#
# model-00004-of-00004.safetensors:  90%|████▌| 1.25G/1.38G [00:05<00:00, 238MB/s]
#
# model-00002-of-00004.safetensors:  28%|█▍   | 1.37G/4.92G [00:05<00:18, 193MB/s]
# model-00003-of-00004.safetensors:  29%|█▍   | 1.41G/4.92G [00:05<00:14, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  28%|█▍   | 1.41G/4.94G [00:05<00:14, 244MB/s]
#
#
# model-00004-of-00004.safetensors:  93%|████▋| 1.28G/1.38G [00:05<00:00, 237MB/s]
#
# model-00002-of-00004.safetensors:  28%|█▍   | 1.39G/4.92G [00:06<00:19, 185MB/s]
# model-00003-of-00004.safetensors:  29%|█▍   | 1.44G/4.92G [00:06<00:14, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:  29%|█▍   | 1.44G/4.94G [00:05<00:14, 246MB/s]
#
#
# model-00004-of-00004.safetensors:  95%|████▊| 1.31G/1.38G [00:05<00:00, 239MB/s]
#
# model-00002-of-00004.safetensors:  29%|█▍   | 1.42G/4.92G [00:06<00:19, 180MB/s]
# model-00003-of-00004.safetensors:  30%|█▍   | 1.47G/4.92G [00:06<00:14, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:  30%|█▍   | 1.47G/4.94G [00:06<00:14, 241MB/s]
#
# model-00002-of-00004.safetensors:  29%|█▍   | 1.44G/4.92G [00:06<00:19, 177MB/s]
#
#
# model-00004-of-00004.safetensors:  97%|████▊| 1.34G/1.38G [00:05<00:00, 235MB/s]
# model-00003-of-00004.safetensors:  31%|█▌   | 1.50G/4.92G [00:06<00:14, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:  30%|█▌   | 1.50G/4.94G [00:06<00:14, 243MB/s]
#
# model-00002-of-00004.safetensors:  30%|█▍   | 1.46G/4.92G [00:06<00:19, 176MB/s]
#
#
# model-00004-of-00004.safetensors: 100%|████▉| 1.37G/1.38G [00:06<00:00, 236MB/s]
# model-00004-of-00004.safetensors: 100%|█████| 1.38G/1.38G [00:06<00:00, 228MB/s]
#
#
#
#
# model-00001-of-00004.safetensors:  31%|█▌   | 1.53G/4.94G [00:06<00:13, 244MB/s]
#
# model-00002-of-00004.safetensors:  30%|█▌   | 1.48G/4.92G [00:06<00:19, 174MB/s]Download complete. Moving file to InternVL2_5-8B/model-00004-of-00004.safetensors
#
# model-00003-of-00004.safetensors:  32%|█▌   | 1.56G/4.92G [00:06<00:13, 241MB/s]
#
#
#
# model-00001-of-00004.safetensors:  32%|█▌   | 1.56G/4.94G [00:06<00:13, 242MB/s]
#
# model-00002-of-00004.safetensors:  31%|█▌   | 1.50G/4.92G [00:06<00:19, 175MB/s]
# model-00003-of-00004.safetensors:  32%|█▌   | 1.59G/4.92G [00:06<00:13, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  32%|█▌   | 1.59G/4.94G [00:06<00:13, 240MB/s]
#
# model-00002-of-00004.safetensors:  31%|█▌   | 1.52G/4.92G [00:06<00:19, 175MB/s]
# model-00003-of-00004.safetensors:  33%|█▋   | 1.63G/4.92G [00:06<00:13, 240MB/s]
#
# model-00002-of-00004.safetensors:  31%|█▌   | 1.54G/4.92G [00:06<00:19, 177MB/s]
#
#
#
# model-00001-of-00004.safetensors:  33%|█▋   | 1.63G/4.94G [00:06<00:13, 241MB/s]
# model-00003-of-00004.safetensors:  34%|█▋   | 1.66G/4.92G [00:06<00:13, 238MB/s]
#
# model-00002-of-00004.safetensors:  32%|█▌   | 1.56G/4.92G [00:06<00:18, 179MB/s]
#
#
#
# model-00001-of-00004.safetensors:  34%|█▋   | 1.66G/4.94G [00:06<00:13, 242MB/s]
# model-00003-of-00004.safetensors:  34%|█▋   | 1.69G/4.92G [00:07<00:13, 238MB/s]
#
# model-00002-of-00004.safetensors:  32%|█▌   | 1.58G/4.92G [00:07<00:18, 180MB/s]
#
#
#
# model-00001-of-00004.safetensors:  34%|█▋   | 1.69G/4.94G [00:07<00:13, 241MB/s]
#
# model-00002-of-00004.safetensors:  33%|█▋   | 1.60G/4.92G [00:07<00:18, 182MB/s]
# model-00003-of-00004.safetensors:  35%|█▋   | 1.72G/4.92G [00:07<00:13, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  35%|█▋   | 1.72G/4.94G [00:07<00:13, 242MB/s]
#
# model-00002-of-00004.safetensors:  33%|█▋   | 1.63G/4.92G [00:07<00:17, 184MB/s]
# model-00003-of-00004.safetensors:  36%|█▊   | 1.75G/4.92G [00:07<00:13, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  35%|█▊   | 1.75G/4.94G [00:07<00:13, 235MB/s]
#
# model-00002-of-00004.safetensors:  33%|█▋   | 1.65G/4.92G [00:07<00:17, 186MB/s]
# model-00003-of-00004.safetensors:  36%|█▊   | 1.78G/4.92G [00:07<00:13, 240MB/s]
#
#
#
# model-00001-of-00004.safetensors:  36%|█▊   | 1.78G/4.94G [00:07<00:13, 242MB/s]
#
# model-00002-of-00004.safetensors:  34%|█▋   | 1.67G/4.92G [00:07<00:17, 189MB/s]
# model-00003-of-00004.safetensors:  37%|█▊   | 1.81G/4.92G [00:07<00:13, 232MB/s]
#
# model-00002-of-00004.safetensors:  34%|█▋   | 1.69G/4.92G [00:07<00:16, 191MB/s]
#
#
#
# model-00001-of-00004.safetensors:  37%|█▊   | 1.81G/4.94G [00:07<00:12, 241MB/s]
# model-00003-of-00004.safetensors:  38%|█▉   | 1.85G/4.92G [00:07<00:12, 238MB/s]
#
# model-00002-of-00004.safetensors:  35%|█▋   | 1.71G/4.92G [00:07<00:16, 192MB/s]
#
#
#
# model-00001-of-00004.safetensors:  37%|█▊   | 1.85G/4.94G [00:07<00:12, 240MB/s]
#
# model-00002-of-00004.safetensors:  35%|█▊   | 1.73G/4.92G [00:07<00:16, 194MB/s]
# model-00003-of-00004.safetensors:  38%|█▉   | 1.88G/4.92G [00:07<00:12, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  38%|█▉   | 1.88G/4.94G [00:07<00:13, 233MB/s]
#
# model-00002-of-00004.safetensors:  36%|█▊   | 1.75G/4.92G [00:07<00:16, 197MB/s]
# model-00003-of-00004.safetensors:  39%|█▉   | 1.91G/4.92G [00:08<00:12, 235MB/s]
#
# model-00002-of-00004.safetensors:  36%|█▊   | 1.77G/4.92G [00:08<00:15, 199MB/s]
#
#
#
# model-00001-of-00004.safetensors:  39%|█▉   | 1.91G/4.94G [00:07<00:13, 233MB/s]
# model-00003-of-00004.safetensors:  39%|█▉   | 1.94G/4.92G [00:08<00:12, 236MB/s]
#
# model-00002-of-00004.safetensors:  36%|█▊   | 1.79G/4.92G [00:08<00:15, 199MB/s]
#
#
#
# model-00001-of-00004.safetensors:  39%|█▉   | 1.94G/4.94G [00:08<00:12, 238MB/s]
#
# model-00002-of-00004.safetensors:  37%|█▊   | 1.81G/4.92G [00:08<00:15, 201MB/s]
# model-00003-of-00004.safetensors:  40%|██   | 1.97G/4.92G [00:08<00:12, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  40%|█▉   | 1.97G/4.94G [00:08<00:12, 241MB/s]
#
# model-00002-of-00004.safetensors:  37%|█▊   | 1.84G/4.92G [00:08<00:15, 202MB/s]
# model-00003-of-00004.safetensors:  41%|██   | 2.00G/4.92G [00:08<00:12, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  41%|██   | 2.00G/4.94G [00:08<00:12, 239MB/s]
#
# model-00002-of-00004.safetensors:  38%|█▉   | 1.87G/4.92G [00:08<00:15, 203MB/s]
# model-00003-of-00004.safetensors:  41%|██   | 2.03G/4.92G [00:08<00:12, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  41%|██   | 2.03G/4.94G [00:08<00:12, 238MB/s]
#
# model-00002-of-00004.safetensors:  39%|█▉   | 1.90G/4.92G [00:08<00:14, 209MB/s]
# model-00003-of-00004.safetensors:  42%|██   | 2.07G/4.92G [00:08<00:12, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  42%|██   | 2.07G/4.94G [00:08<00:12, 237MB/s]
#
# model-00002-of-00004.safetensors:  39%|█▉   | 1.92G/4.92G [00:08<00:14, 208MB/s]
# model-00003-of-00004.safetensors:  43%|██▏  | 2.10G/4.92G [00:08<00:11, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  42%|██   | 2.10G/4.94G [00:08<00:11, 242MB/s]
#
# model-00002-of-00004.safetensors:  40%|█▉   | 1.95G/4.92G [00:08<00:13, 213MB/s]
# model-00003-of-00004.safetensors:  43%|██▏  | 2.13G/4.92G [00:08<00:11, 240MB/s]
#
#
#
# model-00001-of-00004.safetensors:  43%|██▏  | 2.13G/4.94G [00:08<00:11, 239MB/s]
#
# model-00002-of-00004.safetensors:  40%|██   | 1.98G/4.92G [00:09<00:13, 216MB/s]
# model-00003-of-00004.safetensors:  44%|██▏  | 2.16G/4.92G [00:09<00:11, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  44%|██▏  | 2.16G/4.94G [00:09<00:11, 240MB/s]
#
# model-00002-of-00004.safetensors:  41%|██   | 2.01G/4.92G [00:09<00:13, 218MB/s]
# model-00003-of-00004.safetensors:  45%|██▏  | 2.19G/4.92G [00:09<00:11, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  44%|██▏  | 2.19G/4.94G [00:09<00:11, 241MB/s]
#
# model-00002-of-00004.safetensors:  42%|██   | 2.04G/4.92G [00:09<00:13, 219MB/s]
# model-00003-of-00004.safetensors:  45%|██▎  | 2.22G/4.92G [00:09<00:11, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  45%|██▎  | 2.22G/4.94G [00:09<00:11, 241MB/s]
# model-00003-of-00004.safetensors:  46%|██▎  | 2.25G/4.92G [00:09<00:11, 237MB/s]
#
# model-00002-of-00004.safetensors:  42%|██   | 2.08G/4.92G [00:09<00:12, 221MB/s]
#
#
#
# model-00001-of-00004.safetensors:  46%|██▎  | 2.25G/4.94G [00:09<00:11, 241MB/s]
# model-00003-of-00004.safetensors:  46%|██▎  | 2.29G/4.92G [00:09<00:11, 239MB/s]
#
# model-00002-of-00004.safetensors:  43%|██▏  | 2.11G/4.92G [00:09<00:12, 224MB/s]
#
#
#
# model-00001-of-00004.safetensors:  46%|██▎  | 2.29G/4.94G [00:09<00:11, 239MB/s]
# model-00003-of-00004.safetensors:  47%|██▎  | 2.32G/4.92G [00:09<00:10, 239MB/s]
#
# model-00002-of-00004.safetensors:  44%|██▏  | 2.14G/4.92G [00:09<00:12, 226MB/s]
#
#
#
# model-00001-of-00004.safetensors:  47%|██▎  | 2.32G/4.94G [00:09<00:10, 240MB/s]
# model-00003-of-00004.safetensors:  48%|██▍  | 2.35G/4.92G [00:09<00:10, 238MB/s]
#
# model-00002-of-00004.safetensors:  44%|██▏  | 2.17G/4.92G [00:09<00:12, 229MB/s]
#
#
#
# model-00001-of-00004.safetensors:  48%|██▍  | 2.35G/4.94G [00:09<00:10, 242MB/s]
# model-00003-of-00004.safetensors:  48%|██▍  | 2.38G/4.92G [00:10<00:10, 238MB/s]
#
# model-00002-of-00004.safetensors:  45%|██▏  | 2.20G/4.92G [00:10<00:11, 232MB/s]
#
#
#
# model-00001-of-00004.safetensors:  48%|██▍  | 2.38G/4.94G [00:09<00:10, 240MB/s]
# model-00003-of-00004.safetensors:  49%|██▍  | 2.41G/4.92G [00:10<00:10, 238MB/s]
#
# model-00002-of-00004.safetensors:  45%|██▎  | 2.23G/4.92G [00:10<00:13, 198MB/s]
# model-00003-of-00004.safetensors:  50%|██▍  | 2.44G/4.92G [00:10<00:10, 239MB/s]
#
# model-00002-of-00004.safetensors:  46%|██▎  | 2.25G/4.92G [00:10<00:14, 179MB/s]
#
#
#
# model-00001-of-00004.safetensors:  49%|██▍  | 2.41G/4.94G [00:10<00:15, 158MB/s]
# model-00003-of-00004.safetensors:  50%|██▌  | 2.47G/4.92G [00:10<00:10, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  49%|██▍  | 2.43G/4.94G [00:10<00:16, 154MB/s]
# model-00003-of-00004.safetensors:  51%|██▌  | 2.51G/4.92G [00:10<00:11, 206MB/s]
#
# model-00002-of-00004.safetensors:  46%|██▎  | 2.28G/4.92G [00:10<00:20, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:  50%|██▍  | 2.45G/4.94G [00:10<00:16, 149MB/s]
#
#
#
# model-00001-of-00004.safetensors:  50%|██▌  | 2.47G/4.94G [00:10<00:17, 145MB/s]
#
# model-00002-of-00004.safetensors:  47%|██▎  | 2.30G/4.92G [00:10<00:23, 113MB/s]
# model-00003-of-00004.safetensors:  52%|██▌  | 2.54G/4.92G [00:11<00:17, 139MB/s]
#
# model-00002-of-00004.safetensors:  47%|██▎  | 2.32G/4.92G [00:11<00:20, 126MB/s]
#
#
#
# model-00001-of-00004.safetensors:  51%|██▌  | 2.50G/4.94G [00:11<00:20, 118MB/s]
#
# model-00002-of-00004.safetensors:  48%|██▍  | 2.34G/4.92G [00:11<00:19, 131MB/s]
# model-00003-of-00004.safetensors:  52%|██▌  | 2.56G/4.92G [00:11<00:18, 129MB/s]
# model-00003-of-00004.safetensors:  52%|██▌  | 2.58G/4.92G [00:11<00:17, 136MB/s]
#
#
#
# model-00001-of-00004.safetensors:  51%|██▌  | 2.52G/4.94G [00:11<00:21, 110MB/s]
#
# model-00002-of-00004.safetensors:  48%|██▍  | 2.36G/4.92G [00:11<00:22, 116MB/s]
# model-00003-of-00004.safetensors:  53%|██▋  | 2.60G/4.92G [00:11<00:18, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:  51%|██▌  | 2.54G/4.94G [00:11<00:22, 105MB/s]
#
# model-00002-of-00004.safetensors:  48%|██▍  | 2.38G/4.92G [00:11<00:20, 125MB/s]
# model-00003-of-00004.safetensors:  53%|██▋  | 2.62G/4.92G [00:11<00:17, 134MB/s]
#
#
#
# model-00001-of-00004.safetensors:  52%|██▌  | 2.57G/4.94G [00:11<00:18, 131MB/s]
#
# model-00002-of-00004.safetensors:  49%|██▍  | 2.40G/4.92G [00:11<00:21, 115MB/s]
# model-00003-of-00004.safetensors:  54%|██▋  | 2.64G/4.92G [00:11<00:20, 108MB/s]
#
#
#
# model-00001-of-00004.safetensors:  52%|██▌  | 2.59G/4.94G [00:11<00:21, 108MB/s]
#
# model-00002-of-00004.safetensors:  49%|██▍  | 2.42G/4.92G [00:12<00:22, 109MB/s]
# model-00003-of-00004.safetensors:  54%|██▋  | 2.67G/4.92G [00:12<00:16, 135MB/s]
#
#
#
# model-00001-of-00004.safetensors:  53%|██▋  | 2.61G/4.94G [00:11<00:19, 122MB/s]
#
# model-00002-of-00004.safetensors:  50%|██▍  | 2.44G/4.92G [00:12<00:23, 104MB/s]
#
#
#
# model-00001-of-00004.safetensors:  53%|██▋  | 2.63G/4.94G [00:12<00:17, 133MB/s]
# model-00003-of-00004.safetensors:  55%|██▋  | 2.69G/4.92G [00:12<00:16, 135MB/s]
# model-00003-of-00004.safetensors:  55%|██▊  | 2.72G/4.92G [00:12<00:15, 146MB/s]
#
# model-00002-of-00004.safetensors:  50%|██▌  | 2.46G/4.92G [00:12<00:21, 112MB/s]
#
#
#
# model-00001-of-00004.safetensors:  54%|██▋  | 2.65G/4.94G [00:12<00:19, 119MB/s]
#
# model-00002-of-00004.safetensors:  51%|██▌  | 2.49G/4.92G [00:12<00:19, 125MB/s]
# model-00003-of-00004.safetensors:  56%|██▊  | 2.74G/4.92G [00:12<00:15, 140MB/s]
#
#
#
# model-00001-of-00004.safetensors:  54%|██▋  | 2.67G/4.94G [00:12<00:18, 124MB/s]
#
# model-00002-of-00004.safetensors:  51%|██▌  | 2.51G/4.92G [00:12<00:17, 135MB/s]
# model-00003-of-00004.safetensors:  56%|██▊  | 2.77G/4.92G [00:12<00:13, 165MB/s]
# model-00003-of-00004.safetensors:  57%|██▊  | 2.80G/4.92G [00:12<00:11, 184MB/s]
#
#
#
# model-00001-of-00004.safetensors:  55%|██▋  | 2.69G/4.94G [00:12<00:19, 113MB/s]
# model-00003-of-00004.safetensors:  58%|██▉  | 2.83G/4.92G [00:12<00:10, 199MB/s]
#
# model-00002-of-00004.safetensors:  51%|██▌  | 2.53G/4.92G [00:12<00:23, 102MB/s]
# model-00003-of-00004.safetensors:  58%|██▉  | 2.86G/4.92G [00:13<00:09, 210MB/s]
#
#
#
# model-00001-of-00004.safetensors:  55%|██▋  | 2.72G/4.94G [00:12<00:21, 102MB/s]
#
# model-00002-of-00004.safetensors:  52%|██▌  | 2.56G/4.92G [00:13<00:17, 131MB/s]
# model-00003-of-00004.safetensors:  59%|██▉  | 2.89G/4.92G [00:13<00:09, 218MB/s]
#
# model-00002-of-00004.safetensors:  52%|██▌  | 2.58G/4.92G [00:13<00:16, 145MB/s]
#
# model-00002-of-00004.safetensors:  53%|██▋  | 2.60G/4.92G [00:13<00:15, 146MB/s]
# model-00003-of-00004.safetensors:  60%|██▉  | 2.93G/4.92G [00:13<00:09, 204MB/s]
#
#
#
# model-00001-of-00004.safetensors:  55%|██▏ | 2.74G/4.94G [00:13<00:24, 90.5MB/s]
# model-00003-of-00004.safetensors:  60%|██▉  | 2.95G/4.92G [00:13<00:10, 196MB/s]
#
# model-00002-of-00004.safetensors:  53%|██▋  | 2.62G/4.92G [00:13<00:16, 140MB/s]
#
#
#
# model-00001-of-00004.safetensors:  56%|██▏ | 2.75G/4.94G [00:13<00:24, 90.2MB/s]
# model-00003-of-00004.safetensors:  61%|███  | 2.98G/4.92G [00:13<00:09, 206MB/s]
#
#
#
# model-00001-of-00004.safetensors:  56%|██▊  | 2.77G/4.94G [00:13<00:21, 102MB/s]
#
# model-00002-of-00004.safetensors:  54%|██▋  | 2.64G/4.92G [00:13<00:19, 115MB/s]
# model-00003-of-00004.safetensors:  61%|███  | 3.00G/4.92G [00:13<00:12, 155MB/s]
#
#
#
# model-00001-of-00004.safetensors:  57%|██▊  | 2.80G/4.94G [00:13<00:18, 114MB/s]
#
# model-00002-of-00004.safetensors:  54%|██▋  | 2.67G/4.92G [00:13<00:15, 144MB/s]
# model-00003-of-00004.safetensors:  61%|███  | 3.02G/4.92G [00:13<00:11, 160MB/s]
#
# model-00002-of-00004.safetensors:  55%|██▋  | 2.69G/4.92G [00:14<00:15, 142MB/s]
#
#
#
# model-00001-of-00004.safetensors:  57%|██▊  | 2.82G/4.94G [00:14<00:20, 103MB/s]
# model-00003-of-00004.safetensors:  62%|███  | 3.04G/4.92G [00:14<00:12, 153MB/s]
#
# model-00002-of-00004.safetensors:  55%|██▊  | 2.73G/4.92G [00:14<00:13, 165MB/s]
#
#
#
# model-00001-of-00004.safetensors:  58%|██▉  | 2.84G/4.94G [00:14<00:19, 108MB/s]
# model-00003-of-00004.safetensors:  62%|███  | 3.06G/4.92G [00:14<00:12, 143MB/s]
#
# model-00002-of-00004.safetensors:  56%|██▊  | 2.76G/4.92G [00:14<00:11, 184MB/s]
#
# model-00002-of-00004.safetensors:  57%|██▊  | 2.79G/4.92G [00:14<00:10, 200MB/s]
# model-00003-of-00004.safetensors:  63%|███▏ | 3.08G/4.92G [00:14<00:14, 126MB/s]
#
#
#
# model-00001-of-00004.safetensors:  58%|██▉  | 2.86G/4.94G [00:14<00:20, 103MB/s]
#
# model-00002-of-00004.safetensors:  57%|██▊  | 2.82G/4.92G [00:14<00:09, 212MB/s]
#
# model-00002-of-00004.safetensors:  58%|██▉  | 2.85G/4.92G [00:14<00:09, 220MB/s]
# model-00003-of-00004.safetensors:  63%|███▏ | 3.10G/4.92G [00:14<00:15, 120MB/s]
#
#
#
# model-00001-of-00004.safetensors:  58%|██▎ | 2.88G/4.94G [00:14<00:21, 93.5MB/s]
#
# model-00002-of-00004.safetensors:  59%|██▉  | 2.88G/4.92G [00:14<00:09, 225MB/s]
# model-00003-of-00004.safetensors:  64%|███▏ | 3.12G/4.92G [00:14<00:15, 116MB/s]
#
# model-00002-of-00004.safetensors:  59%|██▉  | 2.92G/4.92G [00:15<00:09, 216MB/s]
#
#
#
# model-00001-of-00004.safetensors:  59%|██▎ | 2.90G/4.94G [00:14<00:22, 91.6MB/s]
# model-00003-of-00004.safetensors:  64%|██▌ | 3.15G/4.92G [00:15<00:17, 98.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  59%|██▎ | 2.93G/4.94G [00:15<00:20, 98.9MB/s]
#
# model-00002-of-00004.safetensors:  60%|██▉  | 2.95G/4.92G [00:15<00:10, 185MB/s]
#
#
#
# model-00001-of-00004.safetensors:  59%|██▍ | 2.94G/4.94G [00:15<00:20, 95.6MB/s]
#
# model-00002-of-00004.safetensors:  61%|███  | 2.98G/4.92G [00:15<00:09, 201MB/s]
# model-00003-of-00004.safetensors:  64%|███▏ | 3.17G/4.92G [00:15<00:16, 107MB/s]
#
#
#
# model-00001-of-00004.safetensors:  60%|██▍ | 2.95G/4.94G [00:15<00:23, 86.6MB/s]
#
# model-00002-of-00004.safetensors:  61%|███  | 3.01G/4.92G [00:15<00:10, 189MB/s]
# model-00003-of-00004.safetensors:  65%|███▏ | 3.19G/4.92G [00:15<00:16, 107MB/s]
#
#
#
# model-00001-of-00004.safetensors:  60%|██▍ | 2.96G/4.94G [00:15<00:23, 83.9MB/s]
#
# model-00002-of-00004.safetensors:  62%|███  | 3.03G/4.92G [00:15<00:10, 186MB/s]
# model-00003-of-00004.safetensors:  65%|███▎ | 3.21G/4.92G [00:15<00:15, 111MB/s]
#
# model-00002-of-00004.safetensors:  62%|███  | 3.06G/4.92G [00:15<00:09, 199MB/s]
#
#
#
# model-00001-of-00004.safetensors:  60%|██▍ | 2.97G/4.94G [00:15<00:24, 81.3MB/s]
# model-00003-of-00004.safetensors:  66%|███▎ | 3.23G/4.92G [00:15<00:13, 121MB/s]
#
#
#
# model-00001-of-00004.safetensors:  60%|██▍ | 2.98G/4.94G [00:15<00:23, 84.3MB/s]
#
# model-00002-of-00004.safetensors:  63%|███▏ | 3.09G/4.92G [00:15<00:08, 210MB/s]
#
#
#
# model-00001-of-00004.safetensors:  60%|██▍ | 2.99G/4.94G [00:15<00:23, 83.2MB/s]
#
# model-00002-of-00004.safetensors:  64%|███▏ | 3.12G/4.92G [00:16<00:08, 218MB/s]
# model-00003-of-00004.safetensors:  66%|███▎ | 3.25G/4.92G [00:16<00:14, 118MB/s]
#
#
#
# model-00001-of-00004.safetensors:  61%|██▍ | 3.00G/4.94G [00:16<00:23, 81.4MB/s]
# model-00003-of-00004.safetensors:  67%|███▎ | 3.27G/4.92G [00:16<00:12, 131MB/s]
#
# model-00002-of-00004.safetensors:  64%|███▏ | 3.16G/4.92G [00:16<00:07, 224MB/s]
# model-00003-of-00004.safetensors:  67%|███▎ | 3.30G/4.92G [00:16<00:10, 159MB/s]
#
# model-00002-of-00004.safetensors:  65%|███▏ | 3.19G/4.92G [00:16<00:07, 228MB/s]
#
#
#
# model-00001-of-00004.safetensors:  61%|██▍ | 3.02G/4.94G [00:16<00:21, 88.7MB/s]
# model-00003-of-00004.safetensors:  68%|███▍ | 3.33G/4.92G [00:16<00:08, 181MB/s]
#
# model-00002-of-00004.safetensors:  65%|███▎ | 3.22G/4.92G [00:16<00:07, 228MB/s]
#
#
#
# model-00001-of-00004.safetensors:  62%|███  | 3.05G/4.94G [00:16<00:15, 125MB/s]
# model-00003-of-00004.safetensors:  68%|███▍ | 3.37G/4.92G [00:16<00:07, 197MB/s]
#
# model-00002-of-00004.safetensors:  66%|███▎ | 3.25G/4.92G [00:16<00:08, 202MB/s]
#
#
#
# model-00001-of-00004.safetensors:  62%|███  | 3.08G/4.94G [00:16<00:12, 155MB/s]
# model-00003-of-00004.safetensors:  69%|███▍ | 3.40G/4.92G [00:16<00:07, 209MB/s]
#
#
#
# model-00001-of-00004.safetensors:  63%|███▏ | 3.11G/4.94G [00:16<00:10, 178MB/s]
#
# model-00002-of-00004.safetensors:  67%|███▎ | 3.27G/4.92G [00:16<00:08, 188MB/s]
# model-00003-of-00004.safetensors:  70%|███▍ | 3.43G/4.92G [00:16<00:06, 215MB/s]
#
#
#
# model-00001-of-00004.safetensors:  64%|███▏ | 3.15G/4.94G [00:16<00:09, 195MB/s]
#
# model-00002-of-00004.safetensors:  67%|███▎ | 3.29G/4.92G [00:16<00:09, 167MB/s]
# model-00003-of-00004.safetensors:  70%|███▌ | 3.46G/4.92G [00:16<00:06, 222MB/s]
#
#
#
# model-00001-of-00004.safetensors:  64%|███▏ | 3.18G/4.94G [00:16<00:08, 207MB/s]
#
# model-00002-of-00004.safetensors:  67%|███▎ | 3.31G/4.92G [00:17<00:09, 166MB/s]
# model-00003-of-00004.safetensors:  71%|███▌ | 3.49G/4.92G [00:17<00:06, 226MB/s]
#
#
#
# model-00001-of-00004.safetensors:  65%|███▏ | 3.21G/4.94G [00:17<00:08, 212MB/s]
#
# model-00002-of-00004.safetensors:  68%|███▍ | 3.33G/4.92G [00:17<00:09, 164MB/s]
# model-00003-of-00004.safetensors:  72%|███▌ | 3.52G/4.92G [00:17<00:06, 230MB/s]
#
#
#
# model-00001-of-00004.safetensors:  66%|███▎ | 3.24G/4.94G [00:17<00:07, 223MB/s]
#
# model-00002-of-00004.safetensors:  68%|███▍ | 3.36G/4.92G [00:17<00:09, 164MB/s]
# model-00003-of-00004.safetensors:  72%|███▌ | 3.55G/4.92G [00:17<00:05, 232MB/s]
#
#
#
# model-00001-of-00004.safetensors:  66%|███▎ | 3.27G/4.94G [00:17<00:07, 229MB/s]
#
# model-00002-of-00004.safetensors:  69%|███▍ | 3.38G/4.92G [00:17<00:09, 165MB/s]
# model-00003-of-00004.safetensors:  73%|███▋ | 3.59G/4.92G [00:17<00:05, 234MB/s]
#
#
#
# model-00001-of-00004.safetensors:  67%|███▎ | 3.30G/4.94G [00:17<00:07, 232MB/s]
#
# model-00002-of-00004.safetensors:  69%|███▍ | 3.40G/4.92G [00:17<00:09, 166MB/s]
# model-00003-of-00004.safetensors:  74%|███▋ | 3.62G/4.92G [00:17<00:05, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  68%|███▍ | 3.33G/4.94G [00:17<00:06, 235MB/s]
#
# model-00002-of-00004.safetensors:  70%|███▍ | 3.42G/4.92G [00:17<00:08, 167MB/s]
# model-00003-of-00004.safetensors:  74%|███▋ | 3.65G/4.92G [00:17<00:05, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  68%|███▍ | 3.37G/4.94G [00:17<00:06, 236MB/s]
#
# model-00002-of-00004.safetensors:  70%|███▍ | 3.44G/4.92G [00:17<00:08, 168MB/s]
# model-00003-of-00004.safetensors:  75%|███▋ | 3.68G/4.92G [00:17<00:05, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  69%|███▍ | 3.40G/4.94G [00:17<00:06, 235MB/s]
#
# model-00002-of-00004.safetensors:  70%|███▌ | 3.46G/4.92G [00:18<00:09, 153MB/s]
# model-00003-of-00004.safetensors:  76%|███▊ | 3.71G/4.92G [00:18<00:05, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  69%|███▍ | 3.43G/4.94G [00:17<00:06, 235MB/s]
# model-00003-of-00004.safetensors:  76%|███▊ | 3.74G/4.92G [00:18<00:04, 237MB/s]
#
# model-00002-of-00004.safetensors:  71%|███▌ | 3.48G/4.92G [00:18<00:10, 143MB/s]
#
#
#
# model-00001-of-00004.safetensors:  70%|███▌ | 3.46G/4.94G [00:18<00:06, 233MB/s]
# model-00003-of-00004.safetensors:  77%|███▊ | 3.77G/4.92G [00:18<00:04, 236MB/s]
#
# model-00002-of-00004.safetensors:  71%|███▌ | 3.50G/4.92G [00:18<00:10, 138MB/s]
#
#
#
# model-00001-of-00004.safetensors:  71%|███▌ | 3.49G/4.94G [00:18<00:06, 231MB/s]
# model-00003-of-00004.safetensors:  77%|███▊ | 3.81G/4.92G [00:18<00:04, 237MB/s]
#
# model-00002-of-00004.safetensors:  72%|███▌ | 3.52G/4.92G [00:18<00:10, 137MB/s]
#
#
#
# model-00001-of-00004.safetensors:  71%|███▌ | 3.52G/4.94G [00:18<00:06, 232MB/s]
# model-00003-of-00004.safetensors:  78%|███▉ | 3.84G/4.92G [00:18<00:04, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  72%|███▌ | 3.55G/4.94G [00:18<00:05, 234MB/s]
#
# model-00002-of-00004.safetensors:  72%|███▌ | 3.54G/4.92G [00:18<00:10, 136MB/s]
# model-00003-of-00004.safetensors:  79%|███▉ | 3.87G/4.92G [00:18<00:04, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  73%|███▋ | 3.59G/4.94G [00:18<00:05, 236MB/s]
#
# model-00002-of-00004.safetensors:  73%|███▋ | 3.57G/4.92G [00:18<00:09, 136MB/s]
# model-00003-of-00004.safetensors:  79%|███▉ | 3.90G/4.92G [00:18<00:04, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  73%|███▋ | 3.62G/4.94G [00:18<00:05, 239MB/s]
# model-00003-of-00004.safetensors:  80%|███▉ | 3.93G/4.92G [00:18<00:04, 235MB/s]
#
# model-00002-of-00004.safetensors:  73%|███▋ | 3.59G/4.92G [00:18<00:09, 136MB/s]
#
#
#
# model-00001-of-00004.safetensors:  74%|███▋ | 3.65G/4.94G [00:18<00:05, 239MB/s]
# model-00003-of-00004.safetensors:  81%|████ | 3.96G/4.92G [00:19<00:04, 234MB/s]
#
# model-00002-of-00004.safetensors:  73%|███▋ | 3.61G/4.92G [00:19<00:09, 139MB/s]
#
#
#
# model-00001-of-00004.safetensors:  75%|███▋ | 3.68G/4.94G [00:19<00:05, 233MB/s]
# model-00003-of-00004.safetensors:  81%|████ | 4.00G/4.92G [00:19<00:03, 235MB/s]
#
# model-00002-of-00004.safetensors:  74%|███▋ | 3.63G/4.92G [00:19<00:09, 140MB/s]
#
#
#
# model-00001-of-00004.safetensors:  75%|███▊ | 3.71G/4.94G [00:19<00:05, 239MB/s]
# model-00003-of-00004.safetensors:  82%|████ | 4.03G/4.92G [00:19<00:03, 236MB/s]
#
# model-00002-of-00004.safetensors:  74%|███▋ | 3.65G/4.92G [00:19<00:08, 143MB/s]
#
#
#
# model-00001-of-00004.safetensors:  76%|███▊ | 3.74G/4.94G [00:19<00:04, 240MB/s]
# model-00003-of-00004.safetensors:  83%|████▏| 4.06G/4.92G [00:19<00:03, 238MB/s]
#
# model-00002-of-00004.safetensors:  75%|███▋ | 3.67G/4.92G [00:19<00:08, 146MB/s]
#
#
#
# model-00001-of-00004.safetensors:  76%|███▊ | 3.77G/4.94G [00:19<00:04, 240MB/s]
# model-00003-of-00004.safetensors:  83%|████▏| 4.09G/4.92G [00:19<00:03, 240MB/s]
#
# model-00002-of-00004.safetensors:  75%|███▊ | 3.69G/4.92G [00:19<00:08, 148MB/s]
#
#
#
# Fetching 28 files:   7%|█▊                       | 2/28 [00:20<00:02, 10.33it/s]
# model-00003-of-00004.safetensors:  84%|████▏| 4.12G/4.92G [00:19<00:03, 239MB/s]
#
# model-00002-of-00004.safetensors:  76%|███▊ | 3.71G/4.92G [00:19<00:08, 149MB/s]
#
#
#
# model-00001-of-00004.safetensors:  78%|███▉ | 3.84G/4.94G [00:19<00:04, 238MB/s]
# model-00003-of-00004.safetensors:  84%|████▏| 4.15G/4.92G [00:19<00:03, 237MB/s]
#
# model-00002-of-00004.safetensors:  76%|███▊ | 3.73G/4.92G [00:19<00:07, 152MB/s]
#
#
#
# model-00001-of-00004.safetensors:  78%|███▉ | 3.87G/4.94G [00:19<00:04, 238MB/s]
# model-00003-of-00004.safetensors:  85%|████▎| 4.18G/4.92G [00:20<00:03, 236MB/s]
#
# model-00002-of-00004.safetensors:  76%|███▊ | 3.75G/4.92G [00:20<00:07, 155MB/s]
#
#
#
# model-00001-of-00004.safetensors:  79%|███▉ | 3.90G/4.94G [00:19<00:04, 238MB/s]
# model-00003-of-00004.safetensors:  86%|████▎| 4.22G/4.92G [00:20<00:02, 237MB/s]
#
# model-00002-of-00004.safetensors:  77%|███▊ | 3.77G/4.92G [00:20<00:07, 156MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80%|███▉ | 3.93G/4.94G [00:20<00:04, 239MB/s]
# model-00003-of-00004.safetensors:  86%|████▎| 4.25G/4.92G [00:20<00:02, 238MB/s]
#
# model-00002-of-00004.safetensors:  77%|███▊ | 3.80G/4.92G [00:20<00:07, 156MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80%|████ | 3.96G/4.94G [00:20<00:04, 238MB/s]
# model-00003-of-00004.safetensors:  87%|████▎| 4.28G/4.92G [00:20<00:02, 237MB/s]
#
# model-00002-of-00004.safetensors:  78%|███▉ | 3.82G/4.92G [00:20<00:06, 159MB/s]
# model-00003-of-00004.safetensors:  88%|████▍| 4.31G/4.92G [00:20<00:02, 237MB/s]
#
# model-00002-of-00004.safetensors:  78%|███▉ | 3.84G/4.92G [00:20<00:06, 163MB/s]
# model-00003-of-00004.safetensors:  88%|████▍| 4.34G/4.92G [00:20<00:02, 236MB/s]
#
# model-00002-of-00004.safetensors:  78%|███▉ | 3.86G/4.92G [00:20<00:06, 166MB/s]
#
#
#
# model-00001-of-00004.safetensors:  81%|████ | 4.00G/4.94G [00:20<00:05, 162MB/s]
# model-00003-of-00004.safetensors:  89%|████▍| 4.37G/4.92G [00:20<00:02, 237MB/s]
#
# model-00002-of-00004.safetensors:  79%|███▉ | 3.88G/4.92G [00:20<00:06, 167MB/s]
#
#
#
# model-00001-of-00004.safetensors:  82%|████ | 4.03G/4.94G [00:20<00:05, 180MB/s]
#
# model-00002-of-00004.safetensors:  79%|███▉ | 3.90G/4.92G [00:20<00:05, 171MB/s]
# model-00003-of-00004.safetensors:  90%|████▍| 4.40G/4.92G [00:20<00:02, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  82%|████ | 4.06G/4.94G [00:20<00:04, 194MB/s]
#
# model-00002-of-00004.safetensors:  80%|███▉ | 3.92G/4.92G [00:21<00:05, 174MB/s]
# model-00003-of-00004.safetensors:  90%|████▌| 4.44G/4.92G [00:21<00:02, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  83%|████▏| 4.09G/4.94G [00:20<00:04, 207MB/s]
#
# model-00002-of-00004.safetensors:  80%|████ | 3.94G/4.92G [00:21<00:05, 177MB/s]
# model-00003-of-00004.safetensors:  91%|████▌| 4.47G/4.92G [00:21<00:01, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  83%|████▏| 4.12G/4.94G [00:21<00:03, 218MB/s]
#
# model-00002-of-00004.safetensors:  81%|████ | 3.96G/4.92G [00:21<00:05, 179MB/s]
# model-00003-of-00004.safetensors:  92%|████▌| 4.50G/4.92G [00:21<00:01, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  84%|████▏| 4.15G/4.94G [00:21<00:03, 218MB/s]
#
# model-00002-of-00004.safetensors:  81%|████ | 3.98G/4.92G [00:21<00:05, 181MB/s]
# model-00003-of-00004.safetensors:  92%|████▌| 4.53G/4.92G [00:21<00:01, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  85%|████▏| 4.18G/4.94G [00:21<00:03, 229MB/s]
#
# model-00002-of-00004.safetensors:  81%|████ | 4.01G/4.92G [00:21<00:04, 183MB/s]
# model-00003-of-00004.safetensors:  93%|████▋| 4.56G/4.92G [00:21<00:01, 239MB/s]
#
#
#
# model-00001-of-00004.safetensors:  85%|████▎| 4.22G/4.94G [00:21<00:03, 232MB/s]
#
# model-00002-of-00004.safetensors:  82%|████ | 4.03G/4.92G [00:21<00:04, 185MB/s]
#
# model-00002-of-00004.safetensors:  82%|████ | 4.05G/4.92G [00:21<00:04, 187MB/s]
# model-00003-of-00004.safetensors:  93%|████▋| 4.59G/4.92G [00:21<00:01, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86%|████▎| 4.25G/4.94G [00:21<00:02, 233MB/s]
#
# model-00002-of-00004.safetensors:  83%|████▏| 4.07G/4.92G [00:21<00:04, 190MB/s]
# model-00003-of-00004.safetensors:  94%|████▋| 4.62G/4.92G [00:21<00:01, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|████▎| 4.28G/4.94G [00:21<00:02, 228MB/s]
#
# model-00002-of-00004.safetensors:  83%|████▏| 4.09G/4.92G [00:21<00:04, 190MB/s]
# model-00003-of-00004.safetensors:  95%|████▋| 4.66G/4.92G [00:22<00:01, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|████▎| 4.31G/4.94G [00:21<00:02, 235MB/s]
#
# model-00002-of-00004.safetensors:  84%|████▏| 4.11G/4.92G [00:22<00:04, 193MB/s]
# model-00003-of-00004.safetensors:  95%|████▊| 4.69G/4.92G [00:22<00:00, 236MB/s]
#
# model-00002-of-00004.safetensors:  84%|████▏| 4.13G/4.92G [00:22<00:04, 196MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|████▍| 4.34G/4.94G [00:22<00:02, 235MB/s]
#
# model-00002-of-00004.safetensors:  84%|████▏| 4.15G/4.92G [00:22<00:03, 197MB/s]
# model-00003-of-00004.safetensors:  96%|████▊| 4.72G/4.92G [00:22<00:00, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|████▍| 4.37G/4.94G [00:22<00:02, 236MB/s]
# model-00003-of-00004.safetensors:  97%|████▊| 4.75G/4.92G [00:22<00:00, 236MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|████▍| 4.40G/4.94G [00:22<00:02, 235MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|████▍| 4.44G/4.94G [00:22<00:02, 239MB/s]
# model-00003-of-00004.safetensors:  97%|████▊| 4.78G/4.92G [00:22<00:00, 230MB/s]
#
# model-00002-of-00004.safetensors:  85%|████▏| 4.17G/4.92G [00:22<00:05, 125MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|████▌| 4.47G/4.94G [00:22<00:01, 239MB/s]
# model-00003-of-00004.safetensors:  98%|████▉| 4.81G/4.92G [00:22<00:00, 235MB/s]
#
# model-00002-of-00004.safetensors:  86%|████▎| 4.20G/4.92G [00:22<00:04, 154MB/s]
# model-00003-of-00004.safetensors:  99%|████▉| 4.84G/4.92G [00:22<00:00, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  91%|████▌| 4.50G/4.94G [00:22<00:01, 232MB/s]
#
# model-00002-of-00004.safetensors:  86%|████▎| 4.24G/4.92G [00:22<00:03, 177MB/s]
# model-00003-of-00004.safetensors:  99%|████▉| 4.88G/4.92G [00:22<00:00, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92%|████▌| 4.53G/4.94G [00:22<00:01, 239MB/s]
#
# model-00002-of-00004.safetensors:  87%|████▎| 4.27G/4.92G [00:22<00:03, 193MB/s]
# model-00003-of-00004.safetensors: 100%|████▉| 4.91G/4.92G [00:23<00:00, 237MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92%|████▌| 4.56G/4.94G [00:22<00:01, 239MB/s]
#
# model-00003-of-00004.safetensors: 100%|█████| 4.92G/4.92G [00:23<00:00, 213MB/s]
# Download complete. Moving file to InternVL2_5-8B/model-00003-of-00004.safetensors
#
#
#
#
# model-00001-of-00004.safetensors:  93%|████▋| 4.59G/4.94G [00:23<00:01, 239MB/s]
#
# model-00002-of-00004.safetensors:  88%|████▍| 4.33G/4.92G [00:23<00:02, 206MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94%|████▋| 4.62G/4.94G [00:23<00:01, 238MB/s]
#
# model-00002-of-00004.safetensors:  89%|████▍| 4.36G/4.92G [00:23<00:02, 209MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94%|████▋| 4.66G/4.94G [00:23<00:01, 238MB/s]
#
# model-00002-of-00004.safetensors:  89%|████▍| 4.39G/4.92G [00:23<00:02, 212MB/s]
#
#
#
# model-00001-of-00004.safetensors:  95%|████▋| 4.69G/4.94G [00:23<00:01, 238MB/s]
#
# model-00002-of-00004.safetensors:  90%|████▌| 4.42G/4.92G [00:23<00:02, 216MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96%|████▊| 4.72G/4.94G [00:23<00:00, 239MB/s]
#
# model-00002-of-00004.safetensors:  91%|████▌| 4.46G/4.92G [00:23<00:02, 219MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96%|████▊| 4.75G/4.94G [00:23<00:00, 238MB/s]
#
# model-00002-of-00004.safetensors:  91%|████▌| 4.49G/4.92G [00:23<00:01, 222MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97%|████▊| 4.78G/4.94G [00:23<00:00, 237MB/s]
#
# model-00002-of-00004.safetensors:  92%|████▌| 4.52G/4.92G [00:24<00:01, 223MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97%|████▊| 4.81G/4.94G [00:24<00:00, 237MB/s]
#
# model-00002-of-00004.safetensors:  93%|████▋| 4.55G/4.92G [00:24<00:01, 225MB/s]
#
#
#
# model-00001-of-00004.safetensors:  98%|████▉| 4.84G/4.94G [00:24<00:00, 237MB/s]
#
# model-00002-of-00004.safetensors:  93%|████▋| 4.58G/4.92G [00:24<00:01, 229MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99%|████▉| 4.88G/4.94G [00:24<00:00, 238MB/s]
#
# model-00002-of-00004.safetensors:  94%|████▋| 4.61G/4.92G [00:24<00:01, 231MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99%|████▉| 4.91G/4.94G [00:24<00:00, 236MB/s]
#
# model-00002-of-00004.safetensors:  94%|████▋| 4.65G/4.92G [00:24<00:01, 220MB/s]
#
#
#
# model-00001-of-00004.safetensors: 100%|█████| 4.94G/4.94G [00:24<00:00, 201MB/s]
# Download complete. Moving file to InternVL2_5-8B/model-00001-of-00004.safetensors
# Fetching 28 files:  50%|████████████            | 14/28 [00:25<00:26,  1.86s/it]
#
# model-00002-of-00004.safetensors:  95%|████▊| 4.68G/4.92G [00:24<00:01, 209MB/s]
#
# model-00002-of-00004.safetensors:  96%|████▊| 4.71G/4.92G [00:24<00:00, 217MB/s]
#
# model-00002-of-00004.safetensors:  96%|████▊| 4.74G/4.92G [00:25<00:00, 223MB/s]
#
# model-00002-of-00004.safetensors:  97%|████▊| 4.77G/4.92G [00:25<00:00, 226MB/s]
#
# model-00002-of-00004.safetensors:  98%|████▉| 4.80G/4.92G [00:25<00:00, 229MB/s]
#
# model-00002-of-00004.safetensors:  98%|████▉| 4.83G/4.92G [00:25<00:00, 232MB/s]
#
# model-00002-of-00004.safetensors:  99%|████▉| 4.87G/4.92G [00:25<00:00, 234MB/s]
#
# model-00002-of-00004.safetensors: 100%|█████| 4.92G/4.92G [00:25<00:00, 190MB/s]
# Download complete. Moving file to InternVL2_5-8B/model-00002-of-00004.safetensors
# Fetching 28 files: 100%|████████████████████████| 28/28 [00:26<00:00,  1.07it/s]
# /n/fs/visualai-scr/temp_LLP/ellie/slowfast_kinetics/clip_experiments/InternVL2_5-8B

# %%
# If you have an 80G A100 GPU, you can put the entire model on a single GPU.
# Otherwise, you need to load a model using multiple GPUs, please refer to the `Multiple GPUs` section.
base_dir = "/n/fs/visualai-scr/temp_LLP/ellie/slowfast_kinetics"
path = os.path.join(base_dir, "llm_experiments", "InternVL3-8B")
model = AutoModel.from_pretrained(
    path,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    use_flash_attn=True,
    trust_remote_code=True).eval().cuda()
tokenizer = AutoTokenizer.from_pretrained(path, trust_remote_code=True, use_fast=False)

# set the max number of tiles in `max_num`
generation_config = dict(max_new_tokens=1024, do_sample=False)
# Out:
# FlashAttention2 is not installed.
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00, 27.29it/s]

# %%
def get_index(bound, fps, max_frame, first_idx=0, num_segments=32):
    if bound:
        start, end = bound[0], bound[1]
    else:
        start, end = -100000, 100000
    start_idx = max(first_idx, round(start * fps))
    end_idx = min(round(end * fps), max_frame)
    seg_size = float(end_idx - start_idx) / num_segments
    frame_indices = np.array([
        int(start_idx + (seg_size / 2) + np.round(seg_size * idx))
        for idx in range(num_segments)
    ])
    return frame_indices

# %%
def load_video(frame_dir, bound=None, input_size=448, max_num=1, num_segments=32):
    frame_paths = sorted([
        os.path.join(frame_dir, f)
        for f in os.listdir(frame_dir)
        if f.endswith(('.jpg', '.png'))
    ])
    max_frame = len(frame_paths) - 1
    fps = 30  # estimate manually if unknown

    pixel_values_list, num_patches_list = [], []
    transform = build_transform(input_size=input_size)
    frame_indices = get_index(bound, fps, max_frame, first_idx=0, num_segments=num_segments)

    for idx in frame_indices:
        img = Image.open(frame_paths[idx]).convert('RGB')
        tiles = dynamic_preprocess(img, image_size=input_size, use_thumbnail=True, max_num=max_num)
        pixel_values = [transform(tile) for tile in tiles]
        pixel_values = torch.stack(pixel_values)
        pixel_values_list.append(pixel_values)
        num_patches_list.append(pixel_values.shape[0])

    pixel_values = torch.cat(pixel_values_list)
    return pixel_values, num_patches_list

# %%
import matplotlib.pyplot as plt

# %%
base_dir = "/n/fs/visualai-scr/temp_LLP/ellie/slowfast_kinetics"
video_path = os.path.join(base_dir, "dataset", "action_swap", "original_action_swap", "sample_000000_deadlifting_to_juggling soccer ball_f8dp7wR4GWg_000003_000013_bg_MCV13GHst20_000002_000012")
print("Video Path = ", video_path)

# for index in range(1, 100, 10):
#     pil_img = Image.open(os.path.join(video_path, f"{index:06d}.jpg"))
#     plt.imshow(pil_img)
#     plt.axis('off')  # optional: hides axis ticks
#     plt.show()
# Out:
# Video Path =  /n/fs/visualai-scr/temp_LLP/ellie/slowfast_kinetics/dataset/action_swap/original_action_swap/sample_000000_deadlifting_to_juggling soccer ball_f8dp7wR4GWg_000003_000013_bg_MCV13GHst20_000002_000012

# %%
csv_path = os.path.join(base_dir, "dataset/action_swap/action_swap_mcq.csv")
df = pd.read_csv(csv_path)

# %%
from tqdm import tqdm

# %%
pred_human = 0
pred_bg = 0
total = 0

mapping = {
    1:'A',
    2:'B',
    3:'C',
    4:'D',
    5:'E'
}

rows = []

for idx, row in tqdm(df.iterrows()):
    action_swap_path = row['action_swap_path']
    label_A = row['label_A']
    label_B = row['label_B']
    human_choice = row['human_choice']
    bg_choice = row['background_choice']
    choice_1 = row['choice_1']
    choice_2 = row['choice_2']
    choice_3 = row['choice_3']
    choice_4 = row['choice_4']
    choice_5 = row['choice_5']

    
    pixel_values, num_patches_list = load_video(frame_dir=action_swap_path, num_segments=8, max_num=1)
    pixel_values = pixel_values.to(torch.bfloat16).cuda()
    video_prefix = ''.join([f'Frame{i+1}: \n' for i in range(len(num_patches_list))])
    question = video_prefix + f'What is the action being performed? A) {choice_1} B) {choice_2} C) {choice_3} D) {choice_4} E) {choice_5}'

    response, history = model.chat(tokenizer, pixel_values, question, generation_config,
                                num_patches_list=num_patches_list, history=None, return_history=True)
    
    # print(f'User: {question}\nAssistant: {response}')

    # print("Correct Answer:", mapping[human_choice])

    choice = response[0]
    if choice == mapping[human_choice]:
        pred_human += 1
        # print("Predicted human")

    elif choice == mapping[bg_choice]:
        pred_bg += 1
        # print("Predicted background")
    total += 1

    new_row = row.copy()
    new_row['choice'] = choice
    new_row['choice_is_human'] = (choice==mapping[human_choice])
    new_row['choice_is_bg'] = (choice==mapping[bg_choice])
    rows.append(new_row)

print(f"Predicted Human: {pred_human}/{total} = {pred_human/total:.2f}")
print(f"Predicted Background: {pred_bg}/{total} = {pred_bg/total:.2f}")

df_result = pd.DataFrame(rows)
df_result.to_csv(os.path.join(base_dir, "llm_experiments/internvl3_results.csv"), index=False)
# Out:
# 0it [00:00, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 1it [00:00,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 2it [00:01,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 3it [00:02,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 4it [00:03,  1.11it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 5it [00:04,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 6it [00:05,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 7it [00:05,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 8it [00:06,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 9it [00:07,  1.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 28
#      24 choice_4 = row['choice_4']
#      25 choice_5 = row['choice_5']
# ---> 28 pixel_values, num_patches_list = load_video(frame_dir=action_swap_path, num_segments=8, max_num=1)
#      29 pixel_values = pixel_values.to(torch.bfloat16).cuda()
#      30 video_prefix = ''.join([f'Frame{i+1}: \n' for i in range(len(num_patches_list))])
#
# Cell In[6], line 16, in load_video(frame_dir, bound, input_size, max_num, num_segments)
#      14 for idx in frame_indices:
#      15     img = Image.open(frame_paths[idx]).convert('RGB')
# ---> 16     tiles = dynamic_preprocess(img, image_size=input_size, use_thumbnail=True, max_num=max_num)
#      17     pixel_values = [transform(tile) for tile in tiles]
#      18     pixel_values = torch.stack(pixel_values)
#
# Cell In[3], line 49, in dynamic_preprocess(image, min_num, max_num, image_size, use_thumbnail)
#      46 blocks = target_aspect_ratio[0] * target_aspect_ratio[1]
#      48 # resize the image
# ---> 49 resized_img = image.resize((target_width, target_height))
#      50 processed_images = []
#      51 for i in range(blocks):
#
# File /n/fs/visualai-scr/temp_LLP/ellie/miniconda3/envs/ellie_env2/lib/python3.10/site-packages/PIL/Image.py:2321, in Image.resize(self, size, resample, box, reducing_gap)
#    2309         self = (
#    2310             self.reduce(factor, box=reduce_box)
#    2311             if callable(self.reduce)
#    2312             else Image.reduce(self, factor, box=reduce_box)
#    2313         )
#    2314         box = (
#    2315             (box[0] - reduce_box[0]) / factor_x,
#    2316             (box[1] - reduce_box[1]) / factor_y,
#    2317             (box[2] - reduce_box[0]) / factor_x,
#    2318             (box[3] - reduce_box[1]) / factor_y,
#    2319         )
# -> 2321 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
pixel_values, num_patches_list = load_video(frame_dir=video_path, num_segments=8, max_num=1)
pixel_values = pixel_values.to(torch.bfloat16).cuda()
video_prefix = ''.join([f'Frame{i+1}: \n' for i in range(len(num_patches_list))])
question1 = video_prefix + 'What is the action being performed? A) playing basketball B) juggling soccer ball C) deadlifting D) opening bottle E) climbing a rope'
# Frame1: \nFrame2: \n...\nFrame8: \n{question}
response, history = model.chat(tokenizer, pixel_values, question1, generation_config,
                               num_patches_list=num_patches_list, history=None, return_history=True)
print(f'User: {question1}\nAssistant: {response}')
# Out:
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# User: Frame1:
# Frame2:
# Frame3:
# Frame4:
# Frame5:
# Frame6:
# Frame7:
# Frame8:
# What is the action being performed? A) playing basketball B) juggling soccer ball C) deadlifting D) opening bottle E) climbing a rope
# Assistant: B) juggling soccer ball

# %%
    target_names = ['playing guitar', 'bowling', 'playing saxophone', 'brushing teeth', 
                    'playing basketball', 'tying tie', 'skiing slalom', 'brushing hair', 
                    'punching person (boxing)', 'playing accordion', 'archery', 
                    'catching or throwing frisbee', 'drinking', 'reading book', 
                    'eating ice cream', 'flying kite', 'sweeping floor', 
                    'walking the dog', 'skipping rope', 'clean and jerk', 
                    'eating cake', 'catching or throwing baseball', 
                    'skiing (not slalom or crosscountry)', 'juggling soccer ball', 
                    'deadlifting', 'driving car', 'cleaning windows', 'shooting basketball', 
                    'canoeing or kayaking', 'surfing water', 'playing volleyball', 'opening bottle', 
                    'playing piano', 'writing', 'dribbling basketball', 'reading newspaper', 'playing violin', 
                    'juggling balls', 'playing trumpet', 'smoking', 'shooting goal (soccer)', 'hitting baseball', 
                    'sword fighting', 'climbing ladder', 'playing bass guitar', 'playing tennis', 'climbing a rope', 
                    'golf driving', 'hurdling', 'dunking basketball']
